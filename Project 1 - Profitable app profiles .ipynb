# %% [markdown]
# # Profitable App Profiles for the App Store and Google Play Markets
#
# In this project we will look at what mobile applications on Andriod and iOS attract the most customers.
#
# The company currently build mobile applications that are free to download and that are directed toward an English-speaking audience. In-app ads are their main source of income, this is directly influenced by the number of users using the application.
#
# Our goal for this project is to analyze data to help our developers understand what type of apps are likely to attract more users.

# %% [markdown]
# ## Opening and Exploring the Data
#
# As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# Collecting data for over 4 million apps requires a significant amount of time and money, so we'll try to analyze a sample of the data instead. To avoid spending resources on collecting new data ourselves, we should first try to see if we can find any relevant existing data at no cost. Luckily, these are two data sets that seem suitable for our goals:
#
# - [Play Store](https://www.kaggle.com/lava18/google-play-store-apps), a data set containing data about approximately 10,000 Android apps from Google Play; the data was collected in August 2018.
# - [App Store](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps), a data set containing data about approximately 7,000 iOS apps from the App Store; the data was collected in July 2017.
#
# We'll start by opening and exploring these two data sets.

# %%
from csv import reader

# google dataset
opened_file = open('googleplaystore.csv', encoding='utf8')
read_file = reader(opened_file)
android = list(read_file)
android_header = android[0]
android = android[1:]

# apple dataset
opened_file = open('AppleStore.csv', encoding='utf8')
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios = ios[1:]

# %% [markdown]
# To make them easier to explore, we created a function named `explore_data()` that you can repeatedly use to print rows in a readable way. We'll also add an option for our function to show numbers of rows and columns for any datasets.

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
    
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
print(android_header)
print('\n')
explore_data(android, 0, 2, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# We see that the Google Play data set has 10841 apps and 13 columns. At a quick glance, the columns that might be useful for the purpose of our analysis are 'App', 'Category', 'Reviews', 'Installs', 'Type', 'Price', and 'Genres'.

# %%
print(ios_header)
print('\n')
explore_data(ios, 0, 2, True)
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# Number of rows: 7197
# Number of columns: 17

# %% [markdown]
# We have 7197 iOS apps in this data set, and the columns that seem interesting are: 'track_name', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', and 'prime_genre'.
#
# Not all columns are self-explanatory but details about each column can be found [here](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps).

# %% [markdown]
# ## Deleting Wrong Data
#
# The Google Play data set has a dedicated [discussion section](https://www.kaggle.com/lava18/google-play-store-apps/discussion), and we can see that one of the discussions describes an error at row 10472.

# %%
print(android[10471]) # correct row
# Out:
# ['Xposed Wi-Fi-Pwd', 'PERSONALIZATION', '3.5', '1042', '404k', '100,000+', 'Free', '0', 'Everyone', 'Personalization', 'August 5, 2014', '3.0.0', '4.0.3 and up']

# %%
print(android[10472]) # incorrect row
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
print(android_header) # header
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# The category column seems to be missing the value '1.9' for 'Catogory' makes no sense but fits in with the next column called 'Rating'.
#
# We will delete this row and confirm the number of rows have reduced by one.

# %%
print('Number of rows before:', len(android))
del android[10472]
print('Number of rows after:', len(android))
# Out:
# Number of rows before: 10841
# Number of rows after: 10840

# %% [markdown]
# After checking the App Store data set [discussion section](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/discussion), we did not find any wrong data.

# %% [markdown]
# ## Removing Duplicate Entries
#
# If you explore the Google Play data set long enough or look at the [discussions section](https://www.kaggle.com/lava18/google-play-store-apps/discussion), you'll notice some apps have duplicate entries.

# %%
for app in android:
    name = app[0]
    if name == 'Facebook':
        print(app)
# Out:
# ['Facebook', 'SOCIAL', '4.1', '78158306', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Facebook', 'SOCIAL', '4.1', '78128208', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'August 3, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# We searched for the app Facebook in the data set and found two entries.
#
# We will now count the number of duplicates in this data set.

# %%
duplicate_apps = []
unique_apps = []

for app in android:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
        
print('Number of duplicate apps:', len(duplicate_apps))
print('Expected length:', len(android) - 1181)
# Out:
# Number of duplicate apps: 1181
# Expected length: 9659

# %% [markdown]
# There are 1181 duplicate applications. The Google Play data set should have 9659 applications once the duplicates have been removed.

# %%
print('Examples of duplicate apps:', duplicate_apps[:15])
# Out:
# Examples of duplicate apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software']

# %%
for app in android:
    name = app[0]
    if name == 'Box':
        print(app)
# Out:
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
for app in android:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# By looking at the Instagram duplicate, we can see that the number of reviews are different. We can assume that the entry with the higher number of reviews would be the most up to date one.
#
# Looking at the app Box, we can see that there is no difference. For this case we will delete any duplicates as we come across them.
#
# To remove the duplicates, we will:
#
# - Create a dictionary, where each dictionary key is a unique app name and the corresponding dictionary value is the highest number of reviews of that app.
# - Use the information stored in the dictionary and create a new data set, which will have only one entry per app (and for each app, we'll only select the entry with the highest number of reviews).

# %%
reviews_max = {}
for app in android:
    name = app[0]
    n_reviews = float(app[3])
    if (name in reviews_max) and (reviews_max[name] < n_reviews):
        reviews_max[name] = n_reviews
    elif name not in reviews_max:
        reviews_max[name] = n_reviews
print('Length of reviews_max:', len(reviews_max))
# Out:
# Length of reviews_max: 9659

# %% [markdown]
# The length of reviews_max is the same as the expected length. So we can assume that the duplicates have been removed. We will now use the reviews_max dictionary to create a clean android data set.
#
# In the code cell below:
#
# - We start by initializing two empty lists, android_clean and already_added.
# - We loop through the android data set, and for every iteration:
#  - We isolate the name of the app and the number of reviews.
#  - We add the current row (app) to the android_clean list, and the app name (name) to the already_cleaned list if:
#    - The number of reviews of the current app matches the number of reviews of that app as described in the reviews_max dictionary; and
#    - The name of the app is not already in the already_added list. We need to add this supplementary condition to account for those cases where the highest number of reviews of a duplicate app is the same for more than one entry (for example, the Box app has three entries, and the number of reviews is the same). If we just check for reviews_max[name] == n_reviews, we'll still end up with duplicate entries for some apps.

# %%
android_clean = []
already_added = []

for app in android:
    name = app[0]
    n_reviews = float(app[3])
    if (n_reviews == reviews_max[name]) and (name not in already_added):
        android_clean.append(app)
        already_added.append(name)
explore_data(android_clean, 0, 2, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %% [markdown]
# The data set android_clean has the right number of entries. We can assume there are no duplicates within android_clean.

# %% [markdown]
# ## Removing Non-English Apps
#
# The company only develop apps that are directed to an English-speaking audience. Both data sets contain non-english apps. We will remove all the apps that are not directed to an English-speaking audience.
#
# One way to go about this is to remove each app with a name containing a symbol that is not commonly used in English text — English text usually includes letters from the English alphabet, numbers composed of digits from 0 to 9, punctuation marks (., !, ?, ;), and other symbols (+, *, /).
#
# Behind the scenes, each character we use in a string has a corresponding number associated with it. For instance, the corresponding number for character 'a' is 97, character 'A' is 65, and character '爱' is 29,233. We can get the corresponding number of each character using the ord() built-in function.
#
# The numbers corresponding to the characters we commonly use in an English text are all in the range 0 to 127, according to the ASCII (American Standard Code for Information Interchange) system. Based on this number range, we can build a function that detects whether a character belongs to the set of common English characters or not. If the number is equal to or less than 127, then the character belongs to the set of common English characters.
#
# If an app name contains a character that is greater than 127, then it probably means that the app has a non-English name. To minimize the impact of data loss, we'll only remove an app if its name has more than three characters with corresponding numbers falling outside the ASCII range. This means all English apps with up to three emoji or other special characters will still be labeled as English.

# %%
def app_english(string):
    ascii = 0 # count for charcters above 127
    for character in string:
        if ord(character) > 127:
            ascii += 1
    if ascii > 3:
        return False
    return True
print(app_english('asd?#奇'))
# Out:
# True

# %%
print(app_english('Docs To Go™ Free Office Suite'))
print(app_english('Instachat 😜'))
print(app_english('爱奇艺PPS -《欢乐颂2》电视剧热播'))
# Out:
# True
# True
# False

# %% [markdown]
# The function seems to work fine, English app names using emojis or other symbols that fall outside the ASCII range are being included.
#
# The function is still not perfect, and very few non-English apps might get past our filter, but this seems good enough at this point in our analysis — we shouldn't spend too much time on optimization at this point.
#
# Below, we use the `app_english()` function to filter out the non-English apps for both data sets:

# %%
english_android = []
english_ios = []

for app in android_clean:
    name = app[0]
    if app_english(name):
        english_android.append(app)
for app in ios:
    name = app[2]
    if app_english(name):
        english_ios.append(app)

# %%
explore_data(english_android, 0, 3, True)
print('\n')
explore_data(english_ios, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 6183
# Number of columns: 17

# %% [markdown]
# We are left with 9614 android apps and 6183 iOS apps.

# %% [markdown]
# ## Isolating the Free Apps
#
# We only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our data sets contain both free and non-free apps, we'll need to isolate only the free apps for our analysis.

# %%
print(android_header)
print(ios_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# Price column index for android and iOS respectively are 7, 4.

# %%
free_android = []
free_ios = []

for app in english_android:
    price = app[7]
    if price == '0':
        free_android.append(app)
for app in english_ios:
    price = app[5]
    if price == '0':
        free_ios.append(app)
android_length = print(len(free_android))
ios_length = print(len(free_ios))
# Out:
# 8864
# 3222

# %% [markdown]
# We now have 8864 android apps and 3222 iOS apps.

# %% [markdown]
# ## The Anaylsis
#
# Our aim is to determine the kinds of apps that are likely to attract more users because our revenue is highly influenced by the number of people using our apps.
#
# To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps:
#
# 1. Build a minimal Android version of the app, and add it to Google Play.
# 2. If the app has a good response from users, we develop it further.
# 3. If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.
#
# Because our end goal is to add the app on both Google Play and the App Store, we need to find app profiles that are successful on both markets. For instance, a profile that works well for both markets might be a productivity app that makes use of gamification.
#
# We will begin by getting a sense for what are the most common genres for each market. We will do this by building frequency tables for a few columns in our data sets.

# %% [markdown]
# ## Most Common Genres

# %%
print(android_header)
print(ios_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# We can use the following columns to generate a frequency table to find out what the most common genres are:
# - Android
#     - Category[1]
#     - Genres[9]
# - iOS
#     - Prime_genre[-5]
#
# We'll build two functions we can use to analyze the frequency tables:
#
# - One function to generate frequency tables that show percentages
# - Another function that we can use to display the percentages in a descending order

# %%
def freq_table(dataset, index):
    table = {}
    total = 0
    for app in dataset:
        key = app[index]
        total += 1
        if key in table:
            table[key] += 1
        else:
            table[key] = 1
    table_percent = {}
    for row in table:
        value = table[row]
        name = row
        table_percent[name] = (value / total) * 100
    return table_percent

def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# ### iOS prime genre
# We will start by examining the frequency table for the prime_genre column of the App Store data set.

# %%
print('prime genre'.title())        
display_table(free_ios, -5)
# Out:
# Prime Genre
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# The most common genre for apps that are free and english would be Games at 58% followed by Entertainment at 8%. Photo & Video has 5%, Education at 4% and Social Networking at 3%.
#
# The general impression for free and english apps in the Apple store are that most apps are designed for entertainment purposes. Practical apps such as education, shopping and productivity are more rare.
#
# Even though there are alot of entertainment apps in the Apple store, this does not mean that they have the highest number of users.

# %% [markdown]
# ## Andriod Category and Genres

# %%
print('category'.title())
display_table(free_android, 1)
print('\n')
print('genres'.title())
display_table(free_android, 9)
# Out:
# Category
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# EVENTS : 0.7107400722021661
# PARENTING : 0.6543321299638989
# ART_AND_DESIGN : 0.6430505415162455
# COMICS : 0.6204873646209386
# BEAUTY : 0.5979241877256317
#
#
# Genres
# Tools : 8.449909747292418
# Entertainment : 6.069494584837545
# Education : 5.347472924187725
# Business : 4.591606498194946
# Productivity : 3.892148014440433
# Lifestyle : 3.892148014440433
# Finance : 3.7003610108303246
# Medical : 3.531137184115524
# Sports : 3.463447653429603
# Personalization : 3.3167870036101084
# Communication : 3.2378158844765346
# Action : 3.1024368231046933
# Health & Fitness : 3.0798736462093865
# Photography : 2.944494584837545
# News & Magazines : 2.7978339350180503
# Social : 2.6624548736462095
# Travel & Local : 2.3240072202166067
# Shopping : 2.2450361010830324
# Books & Reference : 2.1435018050541514
# Simulation : 2.0419675090252705
# Dating : 1.861462093862816
# Arcade : 1.8501805054151623
# Video Players & Editors : 1.7712093862815883
# Casual : 1.7599277978339352
# Maps & Navigation : 1.3989169675090252
# Food & Drink : 1.2409747292418771
# Puzzle : 1.128158844765343
# Racing : 0.9927797833935018
# Role Playing : 0.9363718411552346
# Libraries & Demo : 0.9363718411552346
# Auto & Vehicles : 0.9250902527075812
# Strategy : 0.9138086642599278
# House & Home : 0.8235559566787004
# Weather : 0.8009927797833934
# Events : 0.7107400722021661
# Adventure : 0.6768953068592057
# Comics : 0.6092057761732852
# Beauty : 0.5979241877256317
# Art & Design : 0.5979241877256317
# Parenting : 0.4963898916967509
# Card : 0.45126353790613716
# Casino : 0.42870036101083037
# Trivia : 0.41741877256317694
# Educational;Education : 0.39485559566787
# Board : 0.3835740072202166
# Educational : 0.3722924187725632
# Education;Education : 0.33844765342960287
# Word : 0.2594765342960289
# Casual;Pretend Play : 0.236913357400722
# Music : 0.2030685920577617
# Racing;Action & Adventure : 0.16922382671480143
# Puzzle;Brain Games : 0.16922382671480143
# Entertainment;Music & Video : 0.16922382671480143
# Casual;Brain Games : 0.13537906137184114
# Casual;Action & Adventure : 0.13537906137184114
# Arcade;Action & Adventure : 0.12409747292418773
# Action;Action & Adventure : 0.10153429602888085
# Educational;Pretend Play : 0.09025270758122744
# Simulation;Action & Adventure : 0.078971119133574
# Parenting;Education : 0.078971119133574
# Entertainment;Brain Games : 0.078971119133574
# Board;Brain Games : 0.078971119133574
# Parenting;Music & Video : 0.06768953068592057
# Educational;Brain Games : 0.06768953068592057
# Casual;Creativity : 0.06768953068592057
# Art & Design;Creativity : 0.06768953068592057
# Education;Pretend Play : 0.056407942238267145
# Role Playing;Pretend Play : 0.04512635379061372
# Education;Creativity : 0.04512635379061372
# Role Playing;Action & Adventure : 0.033844765342960284
# Puzzle;Action & Adventure : 0.033844765342960284
# Entertainment;Creativity : 0.033844765342960284
# Entertainment;Action & Adventure : 0.033844765342960284
# Educational;Creativity : 0.033844765342960284
# Educational;Action & Adventure : 0.033844765342960284
# Education;Music & Video : 0.033844765342960284
# Education;Brain Games : 0.033844765342960284
# Education;Action & Adventure : 0.033844765342960284
# Adventure;Action & Adventure : 0.033844765342960284
# Video Players & Editors;Music & Video : 0.02256317689530686
# Sports;Action & Adventure : 0.02256317689530686
# Simulation;Pretend Play : 0.02256317689530686
# Puzzle;Creativity : 0.02256317689530686
# Music;Music & Video : 0.02256317689530686
# Entertainment;Pretend Play : 0.02256317689530686
# Casual;Education : 0.02256317689530686
# Board;Action & Adventure : 0.02256317689530686
# Video Players & Editors;Creativity : 0.01128158844765343
# Trivia;Education : 0.01128158844765343
# Travel & Local;Action & Adventure : 0.01128158844765343
# Tools;Education : 0.01128158844765343
# Strategy;Education : 0.01128158844765343
# Strategy;Creativity : 0.01128158844765343
# Strategy;Action & Adventure : 0.01128158844765343
# Simulation;Education : 0.01128158844765343
# Role Playing;Brain Games : 0.01128158844765343
# Racing;Pretend Play : 0.01128158844765343
# Puzzle;Education : 0.01128158844765343
# Parenting;Brain Games : 0.01128158844765343
# Music & Audio;Music & Video : 0.01128158844765343
# Lifestyle;Pretend Play : 0.01128158844765343
# Lifestyle;Education : 0.01128158844765343
# Health & Fitness;Education : 0.01128158844765343
# Health & Fitness;Action & Adventure : 0.01128158844765343
# Entertainment;Education : 0.01128158844765343
# Communication;Creativity : 0.01128158844765343
# Comics;Creativity : 0.01128158844765343
# Casual;Music & Video : 0.01128158844765343
# Card;Action & Adventure : 0.01128158844765343
# Books & Reference;Education : 0.01128158844765343
# Art & Design;Pretend Play : 0.01128158844765343
# Art & Design;Action & Adventure : 0.01128158844765343
# Arcade;Pretend Play : 0.01128158844765343
# Adventure;Education : 0.01128158844765343

# %% [markdown]
# The most common genres in the Category column are family 19%, game 10%, tools 8%, business 5% and lifestyle 4%. The android market has more balance between entertainment and practical apps.
#
# The android market Genres column has alot of different genres. We can also see a similar spread as the category column between entertainment and pratical apps.
#
# The difference between the Genres and the Category columns is not crystal clear, but one thing we can notice is that the Genres column is much more granular (it has more categories). We're only looking for the bigger picture at the moment, so we'll only work with the Category column moving forward.
#
# We would not be able to recommend an app profile using the frequency table for genres as we only know how many apps of that genre are in the market but this does not indicate how many users these apps have.

# %% [markdown]
# ### iOS genre vs ratings
#
# One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre. For the Google Play data set, we can find this information in the `Installs` column, but this information is missing for the App Store data set. As a workaround, we'll take the total number of user ratings as a proxy, which we can find in the `rating_count_tot` app.
#
# We will now calculate the average number of user ratings per app genre on the App Store:

# %%
unique_genres = freq_table(free_ios, -5)
avg_n_rating = [] 
for genre in unique_genres:
    total = 0
    len_genre = 0
    for app in free_ios:
        genre_app = app[-5]
        if genre_app == genre:
            total += float(app[6])
            len_genre += 1
    avg_rating = total / len_genre
    #print(genre, ':', avg_rating)
    tuple_v = (avg_rating, genre)
    avg_n_rating.append(tuple_v)
s_avg = sorted(avg_n_rating, reverse=True)
order = 0
for genre in s_avg:
    order += 1
    print(str(order) + ')', genre[1], ':', genre[0])
# Out:
# 1) Navigation : 86090.33333333333
# 2) Reference : 74942.11111111111
# 3) Social Networking : 71548.34905660378
# 4) Music : 57326.530303030304
# 5) Weather : 52279.892857142855
# 6) Book : 39758.5
# 7) Food & Drink : 33333.92307692308
# 8) Finance : 31467.944444444445
# 9) Photo & Video : 28441.54375
# 10) Travel : 28243.8
# 11) Shopping : 26919.690476190477
# 12) Health & Fitness : 23298.015384615384
# 13) Sports : 23008.898550724636
# 14) Games : 22788.6696905016
# 15) News : 21248.023255813954
# 16) Productivity : 21028.410714285714
# 17) Utilities : 18684.456790123455
# 18) Lifestyle : 16485.764705882353
# 19) Entertainment : 14029.830708661417
# 20) Business : 7491.117647058823
# 21) Education : 7003.983050847458
# 22) Catalogs : 4004.0
# 23) Medical : 612.0

# %% [markdown]
# We can see the top 5 most popular genres in the Apple store above. We will analyse the most popular genre 'Navigation' to find out whether this is a suitable recommendation for the App store.

# %%
for app in free_ios:
    cat = app[-5]
    if cat == 'Navigation':
        print(app[2],':',app[6])
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Geocaching® : 12811
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# Google Maps - Navigation & Transit : 154911

# %% [markdown]
# There are only 6 apps in this category and 2 of them dominate by having the most users. The two apps that have the greatest number of users, do not have adverts within them and would not suit our company profile as we generate our revenue from the ads. Implementing ads to these apps would be possible but users would always opt for the ad free software.
#
# As Navigation is not a good profile for our app, we will look at the next most popular genre 'references'.

# %%
def sort_cat(dataset, name):
    tuples = []
    for app in dataset:
        cat = app[-5]
        if cat == name:
            tuple_v = (float(app[6]), app[2])
            tuples.append(tuple_v)
    display = sorted(tuples, reverse=True)
    order = 0
    for row in display:
        order += 1
        print(str(order) + ')', row[1], ':', row[0])

sort_cat(free_ios, 'Reference')
# Out:
# 1) Bible : 985920.0
# 2) Dictionary.com Dictionary & Thesaurus : 200047.0
# 3) Dictionary.com Dictionary & Thesaurus for iPad : 54175.0
# 4) Google Translate : 26786.0
# 5) Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418.0
# 6) New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588.0
# 7) Merriam-Webster Dictionary : 16849.0
# 8) Night Sky : 12122.0
# 9) City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535.0
# 10) LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693.0
# 11) GUNS MODS for Minecraft PC Edition - Mods Tools : 1497.0
# 12) Guides for Pokémon GO - Pokemon GO News and Cheats : 826.0
# 13) WWDC : 762.0
# 14) Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718.0
# 15) VPN Express : 14.0
# 16) Real Bike Traffic Rider Virtual Reality Glasses : 8.0
# 17) 教えて!goo : 0.0
# 18) Jishokun-Japanese English Dictionary & Translator : 0.0

# %% [markdown]
# References is also dominated by the first two apps.
#
# We will now take a look at Social Networking:

# %%
sort_cat(free_ios, 'Social Networking')
# Out:
# 1) Facebook : 2974676.0
# 2) Pinterest : 1061624.0
# 3) Skype for iPhone : 373519.0
# 4) Messenger : 351466.0
# 5) Tumblr : 334293.0
# 6) WhatsApp Messenger : 287589.0
# 7) Kik : 260965.0
# 8) ooVoo – Free Video Call, Text and Voice : 177501.0
# 9) TextNow - Unlimited Text + Calls : 164963.0
# 10) Viber Messenger – Text & Call : 164249.0
# 11) Followers - Social Analytics For Instagram : 112778.0
# 12) MeetMe - Chat and Meet New People : 97072.0
# 13) We Heart It - Fashion, wallpapers, quotes, tattoos : 90414.0
# 14) InsTrack for Instagram - Analytics Plus More : 85535.0
# 15) Tango - Free Video Call, Voice and Chat : 75412.0
# 16) LinkedIn : 71856.0
# 17) Match™ - #1 Dating App. : 60659.0
# 18) Skype for iPad : 60163.0
# 19) POF - Best Dating App for Conversations : 52642.0
# 20) Timehop : 49510.0
# 21) Find My Family, Friends & iPhone - Life360 Locator : 43877.0
# 22) Whisper - Share, Express, Meet : 39819.0
# 23) Hangouts : 36404.0
# 24) LINE PLAY - Your Avatar World : 34677.0
# 25) WeChat : 34584.0
# 26) Badoo - Meet New People, Chat, Socialize. : 34428.0
# 27) Followers + for Instagram - Follower Analytics : 28633.0
# 28) GroupMe : 28260.0
# 29) Marco Polo Video Walkie Talkie : 27662.0
# 30) Miitomo : 23965.0
# 31) SimSimi : 23530.0
# 32) Grindr - Gay and same sex guys chat, meet and date : 23201.0
# 33) Wishbone - Compare Anything : 20649.0
# 34) imo video calls and chat : 18841.0
# 35) After School - Funny Anonymous School News : 18482.0
# 36) Quick Reposter - Repost, Regram and Reshare Photos : 17694.0
# 37) Weibo HD : 16772.0
# 38) Repost for Instagram : 15185.0
# 39) Live.me – Live Video Chat & Make Friends Nearby : 14724.0
# 40) Nextdoor : 14402.0
# 41) Followers Analytics for Instagram - InstaReport : 13914.0
# 42) YouNow: Live Stream Video Chat : 12079.0
# 43) FollowMeter for Instagram - Followers Tracking : 11976.0
# 44) LINE : 11437.0
# 45) eHarmony™ Dating App - Meet Singles : 11124.0
# 46) Discord - Chat for Gamers : 9152.0
# 47) QQ : 9109.0
# 48) Telegram Messenger : 7573.0
# 49) Weibo : 7265.0
# 50) Periscope - Live Video Streaming Around the World : 6062.0
# 51) Chat for Whatsapp - iPad Version : 5060.0
# 52) QQ HD : 5058.0
# 53) Followers Analysis Tool For Instagram App Free : 4253.0
# 54) live.ly - live video streaming : 4145.0
# 55) Houseparty - Group Video Chat : 3991.0
# 56) SOMA Messenger : 3232.0
# 57) Monkey : 3060.0
# 58) Down To Lunch : 2535.0
# 59) Flinch - Video Chat Staring Contest : 2134.0
# 60) Highrise - Your Avatar Community : 2011.0
# 61) LOVOO - Dating Chat : 1985.0
# 62) PlayStation®Messages : 1918.0
# 63) BOO! - Video chat camera with filters & stickers : 1805.0
# 64) Qzone : 1649.0
# 65) Chatous - Chat with new people : 1609.0
# 66) Kiwi - Q&A : 1538.0
# 67) GhostCodes - a discovery app for Snapchat : 1313.0
# 68) Jodel : 1193.0
# 69) FireChat : 1037.0
# 70) Google Duo - simple video calling : 1033.0
# 71) Fiesta by Tango - Chat & Meet New People : 885.0
# 72) Google Allo — smart messaging : 862.0
# 73) Peach — share vividly : 727.0
# 74) Hey! VINA - Where Women Meet New Friends : 719.0
# 75) Battlefield™ Companion : 689.0
# 76) All Devices for WhatsApp - Messenger for iPad : 682.0
# 77) Chat for Pokemon Go - GoChat : 500.0
# 78) IAmNaughty – Dating App to Meet New People Online : 463.0
# 79) Qzone HD : 458.0
# 80) Zenly - Locate your friends in realtime : 427.0
# 81) League of Legends Friends : 420.0
# 82) 豆瓣 : 407.0
# 83) Candid - Speak Your Mind Freely : 398.0
# 84) 知乎 : 397.0
# 85) Selfeo : 366.0
# 86) Fake-A-Location Free ™ : 354.0
# 87) Popcorn Buzz - Free Group Calls : 281.0
# 88) Fam — Group video calling for iMessage : 279.0
# 89) QQ International : 274.0
# 90) Ameba : 269.0
# 91) SoundCloud Pulse: for creators : 240.0
# 92) Tantan : 235.0
# 93) Cougar Dating & Life Style App for Mature Women : 213.0
# 94) Rawr Messenger - Dab your chat : 180.0
# 95) WhenToPost: Best Time to Post Photos for Instagram : 158.0
# 96) Inke—Broadcast an amazing life : 147.0
# 97) Mustknow - anonymous video Q&A : 53.0
# 98) CTFxCmoji : 39.0
# 99) Lobi : 36.0
# 100) Chain: Collaborate On MyVideo Story/Group Video : 35.0
# 101) botman - Real time video chat : 7.0
# 102) niconico ch : 0.0
# 103) bit-tube - Live Stream Video Chat : 0.0
# 104) MATCH ON LINE chat : 0.0
# 105) LINE BLOG : 0.0
# 106) BestieBox : 0.0

# %% [markdown]
# Social Networking is also heavily influenced by the first two apps. There is also alot of apps in this category. This category does have apps such as Facebook that generate income from ads and are extremely successful.

# %%
sort_cat(free_ios, 'Music')
# Out:
# 1) Pandora - Music & Radio : 1126879.0
# 2) Spotify Music : 878563.0
# 3) Shazam - Discover music, artists, videos & lyrics : 402925.0
# 4) iHeartRadio – Free Music & Radio Stations : 293228.0
# 5) SoundCloud - Music & Audio : 135744.0
# 6) Magic Piano by Smule : 131695.0
# 7) Smule Sing! : 119316.0
# 8) TuneIn Radio - MLB NBA Audiobooks Podcasts Music : 110420.0
# 9) Amazon Music : 106235.0
# 10) SoundHound Song Search & Music Player : 82602.0
# 11) Sonos Controller : 48905.0
# 12) Bandsintown Concerts : 30845.0
# 13) Karaoke - Sing Karaoke, Unlimited Songs! : 28606.0
# 14) My Mixtapez Music : 26286.0
# 15) Sing Karaoke Songs Unlimited with StarMaker : 26227.0
# 16) Ringtones for iPhone & Ringtone Maker : 25403.0
# 17) Musi - Unlimited Music For YouTube : 25193.0
# 18) AutoRap by Smule : 18202.0
# 19) Spinrilla - Mixtapes For Free : 15053.0
# 20) Napster - Top Music & Radio : 14268.0
# 21) edjing Mix:DJ turntable to remix and scratch music : 13580.0
# 22) Free Music - MP3 Streamer & Playlist Manager Pro : 13443.0
# 23) Free Piano app by Yokee : 13016.0
# 24) Google Play Music : 10118.0
# 25) Certified Mixtapes - Hip Hop Albums & Mixtapes : 9975.0
# 26) TIDAL : 7398.0
# 27) YouTube Music : 7109.0
# 28) Nicki Minaj: The Empire : 5196.0
# 29) Sounds app - Music And Friends : 5126.0
# 30) SongFlip - Free Music Streamer : 5004.0
# 31) Simple Radio - Live AM & FM Radio Stations : 4787.0
# 32) Deezer - Listen to your Favorite Music & Playlists : 4677.0
# 33) Ringtones for iPhone with Ringtone Maker : 4013.0
# 34) Bose SoundTouch : 3687.0
# 35) Amazon Alexa : 3018.0
# 36) DatPiff : 2815.0
# 37) Trebel Music - Unlimited Music Downloader : 2570.0
# 38) Free Music Play - Mp3 Streamer & Player : 2496.0
# 39) Acapella from PicPlayPost : 2487.0
# 40) Coach Guitar - Lessons & Easy Tabs For Beginners : 2416.0
# 41) Musicloud - MP3 and FLAC Music Player for Cloud Platforms. : 2211.0
# 42) Piano - Play Keyboard Music Games with Magic Tiles : 1636.0
# 43) Boom: Best Equalizer & Magical Surround Sound : 1375.0
# 44) Music Freedom - Unlimited Free MP3 Music Streaming : 1246.0
# 45) AmpMe - A Portable Social Party Music Speaker : 1047.0
# 46) Medly - Music Maker : 933.0
# 47) Bose Connect : 915.0
# 48) Music Memos : 909.0
# 49) UE BOOM : 612.0
# 50) LiveMixtapes : 555.0
# 51) NOISE : 355.0
# 52) MP3 Music Player & Streamer for Clouds : 329.0
# 53) Musical Video Maker - Create Music clips lip sync : 320.0
# 54) Cloud Music Player - Downloader & Playlist Manager : 319.0
# 55) Remixlive - Remix loops with pads : 288.0
# 56) QQ音乐HD : 224.0
# 57) Blocs Wave - Make & Record Music : 158.0
# 58) PlayGround • Music At Your Fingertips : 150.0
# 59) Music and Chill : 135.0
# 60) The Singing Machine Mobile Karaoke App : 130.0
# 61) radio.de - Der Radioplayer : 64.0
# 62) Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive : 46.0
# 63) NRJ Radio : 38.0
# 64) Smart Music: Streaming Videos and Radio : 17.0
# 65) BOSS Tuner : 13.0
# 66) PetitLyrics : 0.0

# %% [markdown]
# The music category is heavily influenced by the top 3 categories. There is alot of competition in this genre as there are many apps. This category would be a good suggestion as many of these app take revenues from ads.

# %%
sort_cat(free_ios, 'Weather')
# Out:
# 1) The Weather Channel: Forecast, Radar & Alerts : 495626.0
# 2) The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 208648.0
# 3) WeatherBug - Local Weather, Radar, Maps, Alerts : 188583.0
# 4) MyRadar NOAA Weather Radar Forecast : 150158.0
# 5) AccuWeather - Weather for Life : 144214.0
# 6) Yahoo Weather : 112603.0
# 7) Weather Underground: Custom Forecast & Local Radar : 49192.0
# 8) NOAA Weather Radar - Weather Forecast & HD Radar : 45696.0
# 9) Weather Live Free - Weather Forecast & Alerts : 35702.0
# 10) Storm Radar : 22792.0
# 11) QuakeFeed Earthquake Map, Alerts, and News : 6081.0
# 12) Moji Weather - Free Weather Forecast : 2333.0
# 13) Hurricane by American Red Cross : 1158.0
# 14) Forecast Bar : 375.0
# 15) Hurricane Tracker WESH 2 Orlando, Central Florida : 203.0
# 16) FEMA : 128.0
# 17) iWeather - World weather forecast : 80.0
# 18) Weather - Radar - Storm with Morecast App : 78.0
# 19) Yurekuru Call : 53.0
# 20) Weather & Radar : 37.0
# 21) WRAL Weather Alert : 25.0
# 22) Météo-France : 24.0
# 23) JaxReady : 22.0
# 24) Freddy the Frogcaster's Weather Station : 14.0
# 25) Almanac Long-Range Weather Forecast : 12.0
# 26) wetter.com : 0.0
# 27) WarnWetter : 0.0
# 28) TodayAir : 0.0

# %% [markdown]
# This genre is dominated by the first 10 apps. These apps run ad free so I would definitely not suggest this catogory.
#
# Looking at the top 5 genres, I would say social networking and music would be a good suggestion due successful apps that already generate revenues from ads. But getting users from the others apps would be extremely difficult.

# %% [markdown]
# ### Play store
#
# We have data about the number of installs for the Google Play market, so we should be able to get a clearer picture about genre popularity. However, the install numbers don't seem precise enough — we can see that most values are open-ended (100+, 1,000+, 5,000+, etc.):

# %%
display_table(free_android, 5)
# Out:
# 1,000,000+ : 15.726534296028879
# 100,000+ : 11.552346570397113
# 10,000,000+ : 10.548285198555957
# 10,000+ : 10.198555956678701
# 1,000+ : 8.393501805054152
# 100+ : 6.915613718411552
# 5,000,000+ : 6.825361010830325
# 500,000+ : 5.561823104693141
# 50,000+ : 4.7721119133574
# 5,000+ : 4.512635379061372
# 10+ : 3.5424187725631766
# 500+ : 3.2490974729241873
# 50,000,000+ : 2.3014440433213
# 100,000,000+ : 2.1322202166064983
# 50+ : 1.917870036101083
# 5+ : 0.78971119133574
# 1+ : 0.5076714801444043
# 500,000,000+ : 0.2707581227436823
# 1,000,000,000+ : 0.22563176895306858
# 0+ : 0.04512635379061372
# 0 : 0.01128158844765343

# %% [markdown]
# We don't know whether an app with 100,000+ installs has 100,000 installs, 200,000, or 350,000. However, we don't need very precise data for our purposes — we only want to find out which app genres attract the most users, and we don't need perfect precision with respect to the number of users.
#
# We're going to leave the numbers as they are, which means that we'll consider that an app with 100,000+ installs has 100,000 installs, and an app with 1,000,000+ installs has 1,000,000 installs, and so on.
#
# To perform computations, however, we'll need to convert each install number from string to float. This means we need to remove the commas and the plus characters, otherwise the conversion will fail and raise an error.
#
# We'll do this directly in the loop below, where we also compute the average number of installs for each genre (category).

# %%
unique_genres_android = freq_table(free_android, 1)
avg_n = []
for category in unique_genres_android:
    total = 0
    len_category = 0
    for app in free_android:
        category_app = app[1]
        if category_app == category:
            n_installs = app[5]
            n_installs = n_installs.replace('+','')
            n_installs = n_installs.replace(',','')
            n_installs = float(n_installs)
            total += n_installs
            len_category += 1
    avg_n_installs = total / len_category
    #print(category, ':', avg_n_installs)
    tuple_v = (avg_n_installs, category)
    avg_n.append(tuple_v)
s_avg_n = sorted(avg_n, reverse=True)
order = 0
for genre in s_avg_n:
    order += 1
    print(str(order) + ')', genre[1], ':', genre[0])
# Out:
# 1) COMMUNICATION : 38456119.167247385
# 2) VIDEO_PLAYERS : 24727872.452830188
# 3) SOCIAL : 23253652.127118643
# 4) PHOTOGRAPHY : 17840110.40229885
# 5) PRODUCTIVITY : 16787331.344927534
# 6) GAME : 15588015.603248259
# 7) TRAVEL_AND_LOCAL : 13984077.710144928
# 8) ENTERTAINMENT : 11640705.88235294
# 9) TOOLS : 10801391.298666667
# 10) NEWS_AND_MAGAZINES : 9549178.467741935
# 11) BOOKS_AND_REFERENCE : 8767811.894736841
# 12) SHOPPING : 7036877.311557789
# 13) PERSONALIZATION : 5201482.6122448975
# 14) WEATHER : 5074486.197183099
# 15) HEALTH_AND_FITNESS : 4188821.9853479853
# 16) MAPS_AND_NAVIGATION : 4056941.7741935486
# 17) FAMILY : 3695641.8198090694
# 18) SPORTS : 3638640.1428571427
# 19) ART_AND_DESIGN : 1986335.0877192982
# 20) FOOD_AND_DRINK : 1924897.7363636363
# 21) EDUCATION : 1833495.145631068
# 22) BUSINESS : 1712290.1474201474
# 23) LIFESTYLE : 1437816.2687861272
# 24) FINANCE : 1387692.475609756
# 25) HOUSE_AND_HOME : 1331540.5616438356
# 26) DATING : 854028.8303030303
# 27) COMICS : 817657.2727272727
# 28) AUTO_AND_VEHICLES : 647317.8170731707
# 29) LIBRARIES_AND_DEMO : 638503.734939759
# 30) PARENTING : 542603.6206896552
# 31) BEAUTY : 513151.88679245283
# 32) EVENTS : 253542.22222222222
# 33) MEDICAL : 120550.61980830671

# %% [markdown]
# We will examine the top 5 categories:

# %%
def sort_cat_android(dataset, name):
    tuples = []
    for app in dataset:
        cat = app[1]
        if cat == name:
            n_installs = app[5]
            n_installs = n_installs.replace('+','')
            n_installs = n_installs.replace(',','')
            tuple_v = (float(n_installs), app[0])
            tuples.append(tuple_v)
    display = sorted(tuples, reverse=True)
    order = 0
    for row in display:
        order += 1
        print(str(order) + ')', row[1], ':', row[0])
sort_cat_android(free_android, 'COMMUNICATION')
# Out:
# 1) WhatsApp Messenger : 1000000000.0
# 2) Skype - free IM & video calls : 1000000000.0
# 3) Messenger – Text and Video Chat for Free : 1000000000.0
# 4) Hangouts : 1000000000.0
# 5) Google Chrome: Fast & Secure : 1000000000.0
# 6) Gmail : 1000000000.0
# 7) imo free video calls and chat : 500000000.0
# 8) Viber Messenger : 500000000.0
# 9) UC Browser - Fast Download Private & Secure : 500000000.0
# 10) LINE: Free Calls & Messages : 500000000.0
# 11) Google Duo - High Quality Video Calls : 500000000.0
# 12) imo beta free calls and text : 100000000.0
# 13) Yahoo Mail – Stay Organized : 100000000.0
# 14) Who : 100000000.0
# 15) WeChat : 100000000.0
# 16) UC Browser Mini -Tiny Fast Private & Secure : 100000000.0
# 17) Truecaller: Caller ID, SMS spam blocking & Dialer : 100000000.0
# 18) Telegram : 100000000.0
# 19) Opera Mini - fast web browser : 100000000.0
# 20) Opera Browser: Fast and Secure : 100000000.0
# 21) Messenger Lite: Free Calls & Messages : 100000000.0
# 22) Kik : 100000000.0
# 23) KakaoTalk: Free Calls & Text : 100000000.0
# 24) GO SMS Pro - Messenger, Free Themes, Emoji : 100000000.0
# 25) Firefox Browser fast & private : 100000000.0
# 26) BBM - Free Calls & Messages : 100000000.0
# 27) Android Messages : 100000000.0
# 28) free video calls and chat : 50000000.0
# 29) Zalo – Video Call : 50000000.0
# 30) Mail.Ru - Email App : 50000000.0
# 31) Dolphin Browser - Fast, Private & Adblock🐬 : 50000000.0
# 32) Contacts : 50000000.0
# 33) CM Browser - Ad Blocker , Fast Download , Privacy : 50000000.0
# 34) Azar : 50000000.0
# 35) myMail – Email for Hotmail, Gmail and Outlook Mail : 10000000.0
# 36) chomp SMS : 10000000.0
# 37) ZenUI Dialer & Contacts : 10000000.0
# 38) Xperia Link™ : 10000000.0
# 39) Whoscall - Caller ID & Block : 10000000.0
# 40) WhatsCall Free Global Phone Call App & Cheap Calls : 10000000.0
# 41) WhatsApp Business : 10000000.0
# 42) WEB.DE Mail : 10000000.0
# 43) Voxer Walkie Talkie Messenger : 10000000.0
# 44) TouchPal Keyboard - Fun Emoji & Android Keyboard : 10000000.0
# 45) Text SMS : 10000000.0
# 46) Talkray - Free Calls & Texts : 10000000.0
# 47) Talkatone: Free Texts, Calls & Phone Number : 10000000.0
# 48) Puffin Web Browser : 10000000.0
# 49) Psiphon Pro - The Internet Freedom VPN : 10000000.0
# 50) Portable Wi-Fi hotspot : 10000000.0
# 51) Orfox: Tor Browser for Android : 10000000.0
# 52) Opera Mini browser beta : 10000000.0
# 53) Omlet Chat : 10000000.0
# 54) Mr. Number-Block calls & spam : 10000000.0
# 55) Messenger for SMS : 10000000.0
# 56) MegaFon Dashboard : 10000000.0
# 57) ICQ — Video Calls & Chat Messenger : 10000000.0
# 58) Hiya - Caller ID & Block : 10000000.0
# 59) Hangouts Dialer - Call Phones : 10000000.0
# 60) GroupMe : 10000000.0
# 61) Google Voice : 10000000.0
# 62) Google Allo : 10000000.0
# 63) Glide - Video Chat Messenger : 10000000.0
# 64) GO Notifier : 10000000.0
# 65) GMX Mail : 10000000.0
# 66) Free WiFi Connect : 10000000.0
# 67) Free Adblocker Browser - Adblock & Popup Blocker : 10000000.0
# 68) ExDialer - Dialer & Contacts : 10000000.0
# 69) Discord - Chat for Gamers : 10000000.0
# 70) DU Browser—Browse fast & fun : 10000000.0
# 71) Cricket Visual Voicemail : 10000000.0
# 72) Contacts+ : 10000000.0
# 73) Calls Blacklist - Call Blocker : 10000000.0
# 74) CallApp: Caller ID, Blocker & Phone Call Recorder : 10000000.0
# 75) Browser 4G : 10000000.0
# 76) Adblock Browser for Android : 10000000.0
# 77) AT&T Visual Voicemail : 10000000.0
# 78) Your Freedom VPN Client : 5000000.0
# 79) Web Browser & Explorer : 5000000.0
# 80) Sync.ME – Caller ID & Block : 5000000.0
# 81) Skype Lite - Free Video Call & Chat : 5000000.0
# 82) My Vodacom SA : 5000000.0
# 83) My Tele2 : 5000000.0
# 84) Microsoft Edge : 5000000.0
# 85) K-9 Mail : 5000000.0
# 86) JusTalk - Free Video Calls and Fun Video Chat : 5000000.0
# 87) Full Screen Caller ID : 5000000.0
# 88) Ear Agent: Super Hearing : 5000000.0
# 89) Daum Mail - Next Mail : 5000000.0
# 90) Chrome Dev : 5000000.0
# 91) Calls & Text by Mo+ : 5000000.0
# 92) Caller ID & Call Block - DU Caller : 5000000.0
# 93) Call Free – Free Call : 5000000.0
# 94) Call Control - Call Blocker : 5000000.0
# 95) CM Transfer - Share any files with friends nearby : 5000000.0
# 96) CIA - Caller ID & Call Blocker : 5000000.0
# 97) Brave Browser: Fast AdBlocker : 5000000.0
# 98) Bluetooth Auto Connect : 5000000.0
# 99) AT&T Call Protect : 5000000.0
# 100) mysms SMS Text Messaging Sync : 1000000.0
# 101) mail.com mail : 1000000.0
# 102) Wi-Fi Auto-connect : 1000000.0
# 103) Web Browser for Android : 1000000.0
# 104) WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : 1000000.0
# 105) Vonage Mobile® Call Video Text : 1000000.0
# 106) Virtual Walkie Talkie : 1000000.0
# 107) Video Caller Id : 1000000.0
# 108) True Contact - Real Caller ID : 1000000.0
# 109) TracFone My Account : 1000000.0
# 110) Tiny Call Confirm : 1000000.0
# 111) Should I Answer? : 1000000.0
# 112) Seznam.cz : 1000000.0
# 113) Safest Call Blocker : 1000000.0
# 114) SW-100.tch by Callstel : 1000000.0
# 115) RocketDial Dialer & Contacts : 1000000.0
# 116) PHONE for Google Voice & GTalk : 1000000.0
# 117) Ninesky Browser : 1000000.0
# 118) Newton Mail - Email App for Gmail, Outlook, IMAP : 1000000.0
# 119) My magenta : 1000000.0
# 120) My Vodafone (GR) : 1000000.0
# 121) Messaging+ SMS, MMS Free : 1000000.0
# 122) Lite for Facebook Messenger : 1000000.0
# 123) InBrowser - Incognito Browsing : 1000000.0
# 124) Ghostery Privacy Browser : 1000000.0
# 125) Firefox Focus: The privacy browser : 1000000.0
# 126) Email TypeApp - Mail App : 1000000.0
# 127) DW Contacts & Phone & Dialer : 1000000.0
# 128) ClanPlay: Community and Tools for Gamers : 1000000.0
# 129) Caller ID + : 1000000.0
# 130) Call Blocker - Blacklist, SMS Blocker : 1000000.0
# 131) CB Radio Chat - for friends! : 1000000.0
# 132) Burner - Free Phone Number : 1000000.0
# 133) BBMoji - Your personalized BBM Stickers : 1000000.0
# 134) AntennaPict β : 1000000.0
# 135) All Email Providers : 1000000.0
# 136) Adblock Plus for Samsung Internet - Browse safe. : 1000000.0
# 137) AW - free video calls and chat : 1000000.0
# 138) AT&T Messages for Tablet : 1000000.0
# 139) 2ndLine - Second Phone Number : 1000000.0
# 140) Web Browser : 500000.0
# 141) U - Webinars, Meetings & Messenger : 500000.0
# 142) TownWiFi | Wi-Fi Everywhere : 500000.0
# 143) Talkie - Wi-Fi Calling, Chats, File Sharing : 500000.0
# 144) SolMail - All-in-One email app : 500000.0
# 145) LokLok: Draw on a Lock Screen : 500000.0
# 146) Lightning Web Browser : 500000.0
# 147) FreedomPop Messaging Phone/SIM : 500000.0
# 148) BD Data Plan (3G & 4G) : 500000.0
# 149) WiFi Access Point (hotspot) : 100000.0
# 150) T-Mobile DIGITS : 100000.0
# 151) QRZ Assistant : 100000.0
# 152) Portable Wi-Fi hotspot Free : 100000.0
# 153) PlacarTv Futebol Ao Vivo : 100000.0
# 154) Morse Code Reader : 100000.0
# 155) M star Dialer : 100000.0
# 156) K-@ Mail - Email App : 100000.0
# 157) Goodbox - Mega App : 100000.0
# 158) Everbridge : 100000.0
# 159) Channel 19 : 100000.0
# 160) CB On Mobile : 100000.0
# 161) Baby Monitor AV : 100000.0
# 162) BT MeetMe with Dolby Voice : 100000.0
# 163) Antillean Gold Telegram (original version) : 100000.0
# 164) AZ Browser. Private & Download : 100000.0
# 165) X Browser : 50000.0
# 166) N-Com Wizard : 50000.0
# 167) My BF App : 50000.0
# 168) IZ2UUF Morse Koch CW : 50000.0
# 169) HipChat - beta version : 50000.0
# 170) Free Wi-fi HotspoT : 50000.0
# 171) BT Messenger : 50000.0
# 172) BD Internet Packages (Updated) : 50000.0
# 173) AudioBT: BT audio GPS/SMS/Text : 50000.0
# 174) 3G DZ Configuration : 50000.0
# 175) m:go BiH : 10000.0
# 176) [verify-U] VideoIdent : 10000.0
# 177) Ring : 10000.0
# 178) Pocket Prefix Plus : 10000.0
# 179) Mail1Click - Secure Mail : 10000.0
# 180) Jazz Wi-Fi : 10000.0
# 181) Inbox.eu : 10000.0
# 182) Ham Radio Prefixes : 10000.0
# 183) Feel Performer : 10000.0
# 184) Eg Call : 10000.0
# 185) EZ Wifi Notification : 10000.0
# 186) Deaf World DW : 10000.0
# 187) DMR BrandMeister Tool : 10000.0
# 188) ClanHQ : 10000.0
# 189) BT One Phone Mobile App : 10000.0
# 190) BF Browser by Betfilter - Stop Gambling Today! : 10000.0
# 191) BD Dialer : 10000.0
# 192) Ad Blocker Turbo - Adblocker Browser : 10000.0
# 193) Access Point Names : 10000.0
# 194) /u/app : 10000.0
# 195) retteMi.ch : 5000.0
# 196) mail.co.uk Mail : 5000.0
# 197) love sms good morning : 5000.0
# 198) Sat-Fi : 5000.0
# 199) Mircules DX Cluster Lite : 5000.0
# 200) Learn Morse Code - G0HYN Learn Morse : 5000.0
# 201) K-9 Material (unofficial) : 5000.0
# 202) Ham DX Cluster & Spots Finder : 5000.0
# 203) DM for WhatsApp : 5000.0
# 204) DM Talk New : 5000.0
# 205) Council Voting Calculator : 5000.0
# 206) CS Browser Beta : 5000.0
# 207) BT One Voice mobile access : 5000.0
# 208) BD Live Call : 5000.0
# 209) AK Phone : 5000.0
# 210) AG Contacts, Lite edition : 5000.0
# 211) cluster.dk : 1000.0
# 212) Sat-Fi Voice : 1000.0
# 213) SMS Sender - sluzba.cz : 1000.0
# 214) ReadyOp DT : 1000.0
# 215) FO AIRBUS TLSE : 1000.0
# 216) FC Browser - Focus Privacy Browser : 1000.0
# 217) EU Council : 1000.0
# 218) DM Tracker : 1000.0
# 219) Call Blocker & Blacklist : 1000.0
# 220) CS Customizer : 1000.0
# 221) CS Browser | #1 & BEST BROWSER : 1000.0
# 222) CQ-Mobile : 1000.0
# 223) BlueDV AMBE : 1000.0
# 224) BQ Partners : 1000.0
# 225) BN MALLORCA Radio : 1000.0
# 226) BK Chat : 1000.0
# 227) BH Mail : 1000.0
# 228) AV Phone : 1000.0
# 229) AU Call Blocker - Block Unwanted Calls Texts 2018 : 1000.0
# 230) Traffic signs BD : 500.0
# 231) Rádio Sol Nascente DF : 500.0
# 232) Have your say on Europe : 500.0
# 233) ES-1 : 500.0
# 234) CW BLE Peripheral Simulator : 500.0
# 235) CQ-Alert : 500.0
# 236) Best Auto Call Recorder Free : 500.0
# 237) ATC Unico BS : 500.0
# 238) tournaments and more.aj.2 : 100.0
# 239) chat dz : 100.0
# 240) [EF]ShoutBox : 100.0
# 241) Programi podrške EU : 100.0
# 242) MARKET FO : 100.0
# 243) Katalogen.ax : 100.0
# 244) FP Connect : 100.0
# 245) FO STELIA Méaulte : 100.0
# 246) FO SODEXO : 100.0
# 247) FO RCBT : 100.0
# 248) FO PSA Sept-Fons : 100.0
# 249) FO OP St-Nazaire : 100.0
# 250) FO Interim : 100.0
# 251) FO AIRBUS Nantes : 100.0
# 252) EP RSS Reader : 100.0
# 253) EHiN-FH conferenceapp : 100.0
# 254) DG Card : 100.0
# 255) Cy Messenger : 100.0
# 256) Carpooling FH Hagenberg : 100.0
# 257) CW Bluetooth SPP : 100.0
# 258) CJ DVD Rentals : 100.0
# 259) CJ Browser - Fast & Private : 100.0
# 260) CF Chat: Connecting Friends : 100.0
# 261) C W Browser : 100.0
# 262) Bee'ah Employee App : 100.0
# 263) BV : 100.0
# 264) Amadeus GR & CY : 100.0
# 265) Aj.Petra : 100.0
# 266) Hyundai CX Conference : 50.0
# 267) DK TEL Dialer : 50.0
# 268) Cb browser : 50.0
# 269) BS-Mobile : 50.0
# 270) AC-BL : 50.0
# 271) ei : 10.0
# 272) Oklahoma Ag Co-op Council : 10.0
# 273) Hlášenírozhlasu.cz : 10.0
# 274) FP Live : 10.0
# 275) FNH Payment Info : 10.0
# 276) FN Web Radio : 10.0
# 277) Ek IRA : 10.0
# 278) EO Mumbai : 10.0
# 279) EJ messenger : 10.0
# 280) DM - The Offical Messaging App : 10.0
# 281) DK Browser : 10.0
# 282) CK Call NEW : 10.0
# 283) Best Browser BD social networking : 10.0
# 284) BJ - Confidential : 10.0
# 285) Test Server SMS FA : 5.0
# 286) Of the wall Arapaho bk : 5.0
# 287) BA SALES : 1.0

# %% [markdown]
# On average, communication apps have the most installs: 38,456,119. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts), and a few others with over 100 and 500 million installs.

# %%
sort_cat_android(free_android, 'VIDEO_PLAYERS')
# Out:
# 1) YouTube : 1000000000.0
# 2) Google Play Movies & TV : 1000000000.0
# 3) MX Player : 500000000.0
# 4) VivaVideo - Video Editor & Photo Movie : 100000000.0
# 5) VideoShow-Video Editor, Video Maker, Beauty Camera : 100000000.0
# 6) VLC for Android : 100000000.0
# 7) Motorola Gallery : 100000000.0
# 8) Motorola FM Radio : 100000000.0
# 9) Dubsmash : 100000000.0
# 10) Vote for : 50000000.0
# 11) Vigo Video : 50000000.0
# 12) VMate : 50000000.0
# 13) Samsung Video Library : 50000000.0
# 14) Ringdroid : 50000000.0
# 15) MiniMovie - Free Video and Slideshow Editor : 50000000.0
# 16) LIKE – Magic Video Maker & Community : 50000000.0
# 17) KineMaster – Pro Video Editor : 50000000.0
# 18) HD Video Downloader : 2018 Best video mate : 50000000.0
# 19) DU Recorder – Screen Recorder, Video Editor, Live : 50000000.0
# 20) video player for android : 10000000.0
# 21) iMediaShare – Photos & Music : 10000000.0
# 22) YouTube Studio : 10000000.0
# 23) Video Player All Format : 10000000.0
# 24) Video Downloader - for Instagram Repost App : 10000000.0
# 25) Video Downloader : 10000000.0
# 26) Ustream : 10000000.0
# 27) Quik – Free Video Editor for photos, clips, music : 10000000.0
# 28) PowerDirector Video Editor App: 4K, Slow Mo & More : 10000000.0
# 29) Omlet Arcade - Stream, Meet, Play : 10000000.0
# 30) Naruto Shippuden - Watch Free! : 10000000.0
# 31) Music - Mp3 Player : 10000000.0
# 32) Mobizen Screen Recorder for SAMSUNG : 10000000.0
# 33) Magisto Video Editor & Maker : 10000000.0
# 34) Inst Download - Video & Photo : 10000000.0
# 35) HTC Service － DLNA : 10000000.0
# 36) HTC Gallery : 10000000.0
# 37) FrostWire: Torrent Downloader & Music Player : 10000000.0
# 38) FilmoraGo - Free Video Editor : 10000000.0
# 39) Code : 10000000.0
# 40) Cartoon Network App : 10000000.0
# 41) BitTorrent®- Torrent Downloads : 10000000.0
# 42) BSPlayer FREE : 10000000.0
# 43) All Video Downloader : 10000000.0
# 44) AfreecaTV : 10000000.0
# 45) AZ Screen Recorder - No Root : 10000000.0
# 46) YouCut - Video Editor & Video Maker, No Watermark : 5000000.0
# 47) WiFi Baby Monitor - NannyCam : 5000000.0
# 48) Video Editor : 5000000.0
# 49) HTC Service—Video Player : 5000000.0
# 50) Droid Zap by Motorola : 5000000.0
# 51) Adobe Premiere Clip : 5000000.0
# 52) ActionDirector Video Editor - Edit Videos Fast : 5000000.0
# 53) video player : 1000000.0
# 54) iSmart DV : 1000000.0
# 55) iPlayIT for YouTube VR Player : 1000000.0
# 56) XX HD Video downloader-Free Video Downloader : 1000000.0
# 57) Vuze Torrent Downloader : 1000000.0
# 58) Video.Guru - Video Maker : 1000000.0
# 59) Video Status : 1000000.0
# 60) Video Editor,Crop Video,Movie Video,Music,Effects : 1000000.0
# 61) VidPlay : 1000000.0
# 62) VUE: video editor & camcorder : 1000000.0
# 63) VPlayer : 1000000.0
# 64) Tencent Video - Supporting the whole network : 1000000.0
# 65) SVT Play : 1000000.0
# 66) Play Tube : 1000000.0
# 67) OnePlus Gallery : 1000000.0
# 68) OBJECTIVE : 1000000.0
# 69) Multiple Videos at Same Time : 1000000.0
# 70) Mobizen Screen Recorder for LG - Record, Capture : 1000000.0
# 71) Iqiyi (for tablet) : 1000000.0
# 72) HD Video Player : 1000000.0
# 73) HD Video Download for Facebook : 1000000.0
# 74) HD Movie Video Player : 1000000.0
# 75) G Guide Program Guide (SOFTBANK EMOBILE WILLCOM version) : 1000000.0
# 76) Funny videos for whatsapp : 1000000.0
# 77) EZCast – Cast Media to TV : 1000000.0
# 78) DU Privacy-hide apps、sms、file : 1000000.0
# 79) DS video : 1000000.0
# 80) DS photo : 1000000.0
# 81) BluTV : 1000000.0
# 82) BSPlayer ARMv7 VFP CPU support : 1000000.0
# 83) AndStream - Streaming Download : 1000000.0
# 84) All Video Downloader 2018 : 1000000.0
# 85) AX Player -Nougat Video Player : 1000000.0
# 86) Video Player All Format for Android : 500000.0
# 87) GoPlus Cam : 500000.0
# 88) DR TV : 500000.0
# 89) CJ VLC HD Remote (+ Stream) : 500000.0
# 90) amazer - Global Kpop Video Community : 100000.0
# 91) Video Downloader for FB : Video Download with Link : 100000.0
# 92) Sketch 'n' go : 100000.0
# 93) Nero AirBurn : 100000.0
# 94) GoAction : 100000.0
# 95) Free TV series : 100000.0
# 96) Ez Screen Recorder (no ad) : 100000.0
# 97) EZ Web Video Cast | Chromecast : 100000.0
# 98) ES Audio Player ( Shortcut ) : 100000.0
# 99) BGCN TV : 100000.0
# 100) AW Screen Recorder No Root : 100000.0
# 101) AB Repeat Player : 100000.0
# 102) dv Prompter : 50000.0
# 103) bgtime.tv : 50000.0
# 104) ES-IPTV : 50000.0
# 105) BR Series : 50000.0
# 106) AX Video Player : 50000.0
# 107) ACTIVEON CX & CX GOLD : 50000.0
# 108) ek tuhi : 10000.0
# 109) W Box VMS : 10000.0
# 110) MelifeCam-M : 10000.0
# 111) HD VideoDownlaoder For Fb : XXVideo Downloader : 10000.0
# 112) HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017 : 10000.0
# 113) EZ-SEE : 10000.0
# 114) EZ Usenet for Easynews® : 10000.0
# 115) EZ TV Player : 10000.0
# 116) EML UPnP-AV Control Point : 10000.0
# 117) Downvids Helper - One touch DW : 10000.0
# 118) DG Video Editor : 10000.0
# 119) DG UPnP Player Free : 10000.0
# 120) Casper Ssinema : 10000.0
# 121) BS player remote : 10000.0
# 122) BK News Channel : 10000.0
# 123) W Box VMS HD : 5000.0
# 124) Videos downloader for Facebook:fast fb video saver : 5000.0
# 125) Q-See Plus : 5000.0
# 126) M-Sight Pro : 5000.0
# 127) HD Video Player - Video & MP3 Player | AV Player | : 5000.0
# 128) Furrion ES Control : 5000.0
# 129) EF Sidekick : 5000.0
# 130) DZ Popup Video Player : 5000.0
# 131) DV Lottery Photo : 5000.0
# 132) BR Video Player : 5000.0
# 133) BG video - floating video - background video : 5000.0
# 134) Ay : 5000.0
# 135) A-B repeater : 5000.0
# 136) 4K VIDEO PLAYER ULTRA HD : 5000.0
# 137) Music for Youtube - Tube Music BG, Red+ : 1000.0
# 138) Movie Downloader Torrent : Az Torrent : 1000.0
# 139) EZ game screen recorder with audio 1080P : 1000.0
# 140) CINE BR : 1000.0
# 141) BZ Langenthaler Tagblatt : 1000.0
# 142) BC iptv player : 1000.0
# 143) Ay Sabz Gunbad Waly : 1000.0
# 144) AV-IPTV : 1000.0
# 145) YourTube Video Views BG : 500.0
# 146) Video Wallpaper Show : 500.0
# 147) DG Screen Recorder : 500.0
# 148) CX Monthly Tech News : 500.0
# 149) CJ Camcorder : 500.0
# 150) A-Z Screen Recorder - : 500.0
# 151) List iptv FR : 100.0
# 152) EC MANAGER : 100.0
# 153) Bx-WiFi-GI : 100.0
# 154) Bc Vod : 100.0
# 155) BG MUSIC PLAYER - MUSIC PLAYER : 100.0
# 156) AK Lodi Films : 100.0
# 157) AJ Player : 100.0
# 158) CI Stream : 10.0
# 159) Art of F J Taylor : 10.0

# %%
sort_cat_android(free_android, 'SOCIAL')
# Out:
# 1) Instagram : 1000000000.0
# 2) Google+ : 1000000000.0
# 3) Facebook : 1000000000.0
# 4) Snapchat : 500000000.0
# 5) Facebook Lite : 500000000.0
# 6) VK : 100000000.0
# 7) Tumblr : 100000000.0
# 8) Tik Tok - including musical.ly : 100000000.0
# 9) Tango - Live Video Broadcast : 100000000.0
# 10) Pinterest : 100000000.0
# 11) LinkedIn : 100000000.0
# 12) Badoo - Free Chat & Dating App : 100000000.0
# 13) BIGO LIVE - Live Stream : 100000000.0
# 14) ooVoo Video Calls, Messaging & Stories : 50000000.0
# 15) Zello PTT Walkie Talkie : 50000000.0
# 16) SKOUT - Meet, Chat, Go Live : 50000000.0
# 17) POF Free Dating App : 50000000.0
# 18) MeetMe: Chat & Meet New People : 50000000.0
# 19) textPlus: Free Text & Calls : 10000000.0
# 20) magicApp Calling & Messaging : 10000000.0
# 21) YouNow: Live Stream Video Chat : 10000000.0
# 22) We Heart It : 10000000.0
# 23) Waplog - Free Chat, Dating App, Meet Singles : 10000000.0
# 24) TextNow - free text + calls : 10000000.0
# 25) Text free - Free Text + Call : 10000000.0
# 26) Text Me: Text Free, Call Free, Second Phone Number : 10000000.0
# 27) Tapatalk - 100,000+ Forums : 10000000.0
# 28) Tagged - Meet, Chat & Dating : 10000000.0
# 29) SayHi Chat, Meet New People : 10000000.0
# 30) Quora : 10000000.0
# 31) Phone Tracker : Family Locator : 10000000.0
# 32) Periscope - Live Video : 10000000.0
# 33) Path : 10000000.0
# 34) Mico- Stranger Chat Random video Chat, Live, Meet : 10000000.0
# 35) Messenger Messenger : 10000000.0
# 36) Messenger : 10000000.0
# 37) Messages, Text and Video Chat for Messenger : 10000000.0
# 38) LiveMe - Video chat, new friends, and make money : 10000000.0
# 39) Legend - Animate Text in Video : 10000000.0
# 40) LOVOO : 10000000.0
# 41) Kate Mobile for VK : 10000000.0
# 42) Jaumo Dating, Flirt & Live Video : 10000000.0
# 43) HTC Social Plugin - Facebook : 10000000.0
# 44) Grindr - Gay chat : 10000000.0
# 45) Free phone calls, free texting SMS on free number : 10000000.0
# 46) Find My Friends : 10000000.0
# 47) Dating App, Flirt & Chat : W-Match : 10000000.0
# 48) Amino: Communities and Chats : 10000000.0
# 49) Who Viewed My Facebook Profile - Stalkers Visitors : 5000000.0
# 50) Whisper : 5000000.0
# 51) Web Browser & Fast Explorer : 5000000.0
# 52) VidStatus app - Status Videos & Status Downloader : 5000000.0
# 53) Timehop : 5000000.0
# 54) Text Free: WiFi Calling App : 5000000.0
# 55) Telegram X : 5000000.0
# 56) SPARK - Live random video chat & meet new people : 5000000.0
# 57) Nextdoor - Local neighborhood news & classifieds : 5000000.0
# 58) Meetup : 5000000.0
# 59) Meet – Talk to Strangers Using Random Video Chat : 5000000.0
# 60) Instachat 😜 : 5000000.0
# 61) Hornet - Gay Social Network : 5000000.0
# 62) Hide Something - Photo, Video : 5000000.0
# 63) HOLLA Live: Meet New People via Random Video Chat : 5000000.0
# 64) FunForMobile Ringtones & Chat : 5000000.0
# 65) Frim: get new friends on local chat rooms : 5000000.0
# 66) Fame Boom for Real Followers, Likes : 5000000.0
# 67) Blogger : 5000000.0
# 68) 💘 WhatsLov: Smileys of love, stickers and GIF : 1000000.0
# 69) pixiv : 1000000.0
# 70) Wishbone - Compare Anything : 1000000.0
# 71) VMate Lite - Funny Short Videos Social Network : 1000000.0
# 72) U LIVE – Video Chat & Stream : 1000000.0
# 73) TwitCasting Live : 1000000.0
# 74) The Messenger App : 1000000.0
# 75) Stickers for Facebook : 1000000.0
# 76) Snaappy – 3D fun AR core communication platform : 1000000.0
# 77) Moment : 1000000.0
# 78) MobilePatrol Public Safety App : 1000000.0
# 79) Messenger Pro : 1000000.0
# 80) Love Sticker : 1000000.0
# 81) Love Images : 1000000.0
# 82) Lesbian Chat & Dating - SPICY : 1000000.0
# 83) Jodel - The Hyperlocal App : 1000000.0
# 84) GUYZ - Gay Chat & Gay Dating : 1000000.0
# 85) Frontback - Social Photos : 1000000.0
# 86) Friendly for Facebook : 1000000.0
# 87) Free Messages, Video, Chat,Text for Messenger Plus : 1000000.0
# 88) FollowMeter for Instagram : 1000000.0
# 89) Fiesta by Tango - Find, Meet and Make New Friends : 1000000.0
# 90) Faster for Facebook Lite : 1000000.0
# 91) Family GPS tracker KidControl + GPS by SMS Locator : 1000000.0
# 92) Facebook Local : 1000000.0
# 93) Facebook Creator : 1000000.0
# 94) EZ Video Download for Facebook : 1000000.0
# 95) Couple - Relationship App : 1000000.0
# 96) Banjo : 1000000.0
# 97) BOO! - Next Generation Messenger : 1000000.0
# 98) B-Messenger Video Chat : 1000000.0
# 99) All Social Networks : 1000000.0
# 100) +Download 4 Instagram Twitter : 1000000.0
# 101) Web Browser ( Fast & Secure Web Explorer) : 500000.0
# 102) Verdad o Reto : 500000.0
# 103) Swift for Facebook Lite : 500000.0
# 104) Stream - Live Video Community : 500000.0
# 105) Qeek for Instagram - Zoom profile insta DP : 500000.0
# 106) Puffin for Facebook : 500000.0
# 107) Profile Tracker - Who Viewed My Facebook Profile : 500000.0
# 108) Pink Color for Facebook : 500000.0
# 109) Mirrativ: Live Stream Any App : 500000.0
# 110) Greeting Cards & Wishes : 500000.0
# 111) Gayvox - Gay Lesbian Bi Dating : 500000.0
# 112) Fake Chat (Direct Message) : 500000.0
# 113) Daddyhunt: Gay Dating : 500000.0
# 114) Bloglovin' : 500000.0
# 115) uCiC- Videos and Photos on demand : 100000.0
# 116) YAY - TBH : 100000.0
# 117) What U See : 100000.0
# 118) The Video Messenger App : 100000.0
# 119) Social network all in one 2018 : 100000.0
# 120) See U - Random video chat, video chat : 100000.0
# 121) Phoenix - Facebook & Messenger : 100000.0
# 122) Patook - make platonic friends : 100000.0
# 123) Meet U - Get Friends for Snapchat, Kik & Instagram : 100000.0
# 124) MB Notifications for FB (Free) : 100000.0
# 125) KPOP Amino for K-Pop Entertainment : 100000.0
# 126) KDRAMA Amino for K-Drama Fans : 100000.0
# 127) FutureNet your social app : 100000.0
# 128) Fr Daoud Lamei : 100000.0
# 129) Faster Social for Facebook : 100000.0
# 130) Dr. B.R.Ambedkar : 100000.0
# 131) Dr B R Ambedkar (Jai Bhim) : 100000.0
# 132) Dating.dk : 100000.0
# 133) DP and Status for WhatsApp 2018 : 100000.0
# 134) Chat For Strangers - Video Chat : 100000.0
# 135) Blogaway for Android (Blogger) : 100000.0
# 136) Undertale AU Amino : 50000.0
# 137) Rande.cz : 50000.0
# 138) Hashtags For Likes.co : 50000.0
# 139) Golden telegram : 50000.0
# 140) FCB Connect - FC Barcelona : 50000.0
# 141) Equestria Amino for MLP : 50000.0
# 142) EXO-L Amino for EXO Fans : 50000.0
# 143) CP Dialer : 50000.0
# 144) BT Dating -Find your match, help cupid, be social : 50000.0
# 145) Anime et Manga Amino en Français : 50000.0
# 146) Unlimited Group Links - Whatsapp, FB, Telegram : 10000.0
# 147) U-Report : 10000.0
# 148) Stickers for Imo, fb, whatsapp : 10000.0
# 149) Share G - Images Sharing - Wallpapers App : 10000.0
# 150) Mini for Facebook lite : 10000.0
# 151) Mali J : 10000.0
# 152) Lite Messenger for Facebook Lite : 10000.0
# 153) Jamaa Amino for Animal Jam : 10000.0
# 154) Ek Maratha : 10000.0
# 155) Eddsworld Amino : 10000.0
# 156) Digi-TV.ch : 10000.0
# 157) Daily Murli Saar Widget : 10000.0
# 158) DM Me - Chat : 10000.0
# 159) Cyprus Police : 10000.0
# 160) Best DP and Status : 10000.0
# 161) BT Communicator : 10000.0
# 162) BK Traffic Control cum Chart : 10000.0
# 163) Au Pair : 10000.0
# 164) funny Image Comments for FB : 5000.0
# 165) TNEB Bill Online Payment (Tamil) : 5000.0
# 166) TN e Sevai TN EB Bill Patta Citta EC Birth All Hub : 5000.0
# 167) Profile Pictures and DP for Whatsapp : 5000.0
# 168) Instant DP Downloader for Instagram : 5000.0
# 169) Dp for Facebook : 5000.0
# 170) Dp For Whatsapp : 5000.0
# 171) DP Display Pictures Life Quotes Motivational GM : 5000.0
# 172) DM for IG 😘 - Image & Video Saver for Instagram : 5000.0
# 173) DB Event App : 5000.0
# 174) Check Your Visitors on FB ? : 5000.0
# 175) signály.cz : 1000.0
# 176) eChallan Andhra Pradesh (AP) : 1000.0
# 177) Zdravei.BG : 1000.0
# 178) V Bucks ProTips New : 1000.0
# 179) TN EC Online New : 1000.0
# 180) Students.ch : 1000.0
# 181) Sabka Malik Ek Sai : 1000.0
# 182) Noticias DF : 1000.0
# 183) Media Sosial TNI AU : 1000.0
# 184) Join R, Community Engagement : 1000.0
# 185) H letter images : 1000.0
# 186) European Solidarity Corps : 1000.0
# 187) DW Streaming : 1000.0
# 188) DC Comics Amino : 1000.0
# 189) CG Districts : 1000.0
# 190) Black Social : 1000.0
# 191) BR Chat Bot : 1000.0
# 192) BGKontakti Vienna BG Kontakti : 1000.0
# 193) BGKontakti Bayern BG Kontakti : 1000.0
# 194) BG LINKED (BGLINKED) : 1000.0
# 195) Auto DM for Twitter 🔥 : 1000.0
# 196) Alarm.fo – choose your info : 1000.0
# 197) iCard BD Plus : 500.0
# 198) Downloader plus for FB : 500.0
# 199) DK Murali : 500.0
# 200) DF BugMeNot : 500.0
# 201) Br Browser : 500.0
# 202) BGKontakti London BG Kontakti : 500.0
# 203) i-share AF/KLM (AFKL ishare) : 100.0
# 204) TN Patta /Chitta /EC New : 100.0
# 205) Rejoin Your Ex : 100.0
# 206) Naruto & Boruto FR : 100.0
# 207) Myjob@BM : 100.0
# 208) Movement BE : 100.0
# 209) Message AI - Write Better Messages (Free) : 100.0
# 210) GirlTalk.dk : 100.0
# 211) Frases Cristianas de Esperanza y Fe : 100.0
# 212) Evasion.bz : 100.0
# 213) Eternal Light AG : 100.0
# 214) Discípulos em BH : 100.0
# 215) DV Statistics : 100.0
# 216) DM Storage (for twitter) : 100.0
# 217) CJ Gospel Hour : 100.0
# 218) Alumni BJ : 100.0
# 219) UP EB Bill Payment & Details : 50.0
# 220) FB Advanced Search : 50.0
# 221) EG Way Life : 50.0
# 222) Coupe Adhémar EY 2017 : 50.0
# 223) quran-DZ : 10.0
# 224) bm-Events : 10.0
# 225) Reisedealz.eu : 10.0
# 226) Otto DM : 10.0
# 227) News Dz : 10.0
# 228) Hum Ek Hain 2.02 : 10.0
# 229) EO RAIPUR : 10.0
# 230) DN Blog : 10.0
# 231) BA 3 Banjarmasin : 10.0
# 232) CB Heroes : 5.0
# 233) C.P. CERVANTES (TOBARRA) : 5.0
# 234) BH Connect : 1.0
# 235) Amleen Ey : 1.0
# 236) Pekalongan CJ : 0.0

# %%
sort_cat_android(free_android, 'PHOTOGRAPHY')
# Out:
# 1) Google Photos : 1000000000.0
# 2) Z Camera - Photo Editor, Beauty Selfie, Collage : 100000000.0
# 3) YouCam Perfect - Selfie Photo Editor : 100000000.0
# 4) YouCam Makeup - Magic Selfie Makeovers : 100000000.0
# 5) Sweet Selfie - selfie camera, beauty cam, photo edit : 100000000.0
# 6) S Photo Editor - Collage Maker , Photo Collage : 100000000.0
# 7) Retrica : 100000000.0
# 8) PicsArt Photo Studio: Collage Maker & Pic Editor : 100000000.0
# 9) PhotoGrid: Video & Pic Collage Maker, Photo Editor : 100000000.0
# 10) Photo Editor Pro : 100000000.0
# 11) Photo Editor Collage Maker Pro : 100000000.0
# 12) Photo Collage Editor : 100000000.0
# 13) LINE Camera - Photo editor : 100000000.0
# 14) Cymera Camera- Photo Editor, Filter,Collage,Layout : 100000000.0
# 15) Candy Camera - selfie, beauty camera, photo editor : 100000000.0
# 16) Camera360: Selfie Photo Editor with Funny Sticker : 100000000.0
# 17) BeautyPlus - Easy Photo Editor & Selfie Camera : 100000000.0
# 18) B612 - Beauty & Filter Camera : 100000000.0
# 19) AR effect : 100000000.0
# 20) Video Editor Music,Cut,No Crop : 50000000.0
# 21) VSCO : 50000000.0
# 22) Square InPic - Photo Editor & Collage Maker : 50000000.0
# 23) Snapseed : 50000000.0
# 24) Selfie Camera - Photo Editor & Filter & Sticker : 50000000.0
# 25) SNOW - AR Camera : 50000000.0
# 26) Pixlr – Free Photo Editor : 50000000.0
# 27) Pic Collage - Photo Editor : 50000000.0
# 28) PhotoWonder: Pro Beauty Photo Editor Collage Maker : 50000000.0
# 29) Photo Lab Picture Editor: face effects, art frames : 50000000.0
# 30) Photo Effects Pro : 50000000.0
# 31) Photo Editor by Aviary : 50000000.0
# 32) Photo Editor Selfie Camera Filter & Mirror Image : 50000000.0
# 33) Motorola Camera : 50000000.0
# 34) MomentCam Cartoons & Stickers : 50000000.0
# 35) MakeupPlus - Your Own Virtual Makeup Artist : 50000000.0
# 36) Keepsafe Photo Vault: Hide Private Photos & Videos : 50000000.0
# 37) InstaSize Photo Filters & Collage Editor : 50000000.0
# 38) InstaBeauty -Makeup Selfie Cam : 50000000.0
# 39) Boomerang from Instagram : 50000000.0
# 40) Adobe Photoshop Express:Photo Editor Collage Maker : 50000000.0
# 41) ASUS Gallery : 50000000.0
# 42) Wondershare PowerCam : 10000000.0
# 43) Sweet Snap - live filter, Selfie photo edit : 10000000.0
# 44) Sweet Camera - Selfie Filters, Beauty Camera : 10000000.0
# 45) Scoompa Video - Slideshow Maker and Video Editor : 10000000.0
# 46) RetroSelfie - Selfie Editor : 10000000.0
# 47) Retro Camera : 10000000.0
# 48) QuickPic - Photo Gallery with Google Drive Support : 10000000.0
# 49) Pixlr-o-matic : 10000000.0
# 50) PixelLab - Text on pictures : 10000000.0
# 51) PhotoScan by Google Photos : 10000000.0
# 52) PhotoLayers〜Superimpose,Eraser : 10000000.0
# 53) PhotoFunia : 10000000.0
# 54) PhotoDirector Photo Editor App : 10000000.0
# 55) Photo Studio : 10000000.0
# 56) Photo Mixer : 10000000.0
# 57) Photo Frames : 10000000.0
# 58) Photo Frame : 10000000.0
# 59) Photo Editor by BeFunky : 10000000.0
# 60) Photo Editor : 10000000.0
# 61) Photo Collage Maker : 10000000.0
# 62) Photo Collage - Layout Editor : 10000000.0
# 63) Photo Collage - InstaMag : 10000000.0
# 64) Phonto - Text on Photos : 10000000.0
# 65) PIP Selfie Camera Photo Editor : 10000000.0
# 66) Open Camera : 10000000.0
# 67) No Crop & Square for Instagram : 10000000.0
# 68) My Photo Keyboard : 10000000.0
# 69) Mirror Photo:Editor Collage (HD) : 10000000.0
# 70) Meitu – Beauty Cam, Easy Photo Editor : 10000000.0
# 71) Love Collage - Photo Editor : 10000000.0
# 72) LightX Photo Editor & Photo Effects : 10000000.0
# 73) HD Camera for Android : 10000000.0
# 74) HD Camera Ultra : 10000000.0
# 75) GoPro (formerly Capture) : 10000000.0
# 76) Free Slideshow Maker & Video Editor : 10000000.0
# 77) Fotor Photo Editor - Photo Collage & Photo Effects : 10000000.0
# 78) Font Studio- Photo Texts Image : 10000000.0
# 79) Flickr : 10000000.0
# 80) Facejjang : 10000000.0
# 81) FaceApp : 10000000.0
# 82) Face Filter, Selfie Editor - Sweet Camera : 10000000.0
# 83) EyeEm - Camera & Photo Filter : 10000000.0
# 84) Color Touch Effects : 10000000.0
# 85) Candy selfie - photo editor, live filter camera : 10000000.0
# 86) Cameringo Lite. Filters Camera : 10000000.0
# 87) Camera360 Lite - Selfie Camera : 10000000.0
# 88) Camera for Android : 10000000.0
# 89) Camera MX - Free Photo & Video Camera : 10000000.0
# 90) Camera FV-5 Lite : 10000000.0
# 91) Bokeh (Background defocus) : 10000000.0
# 92) Blur Image Background : 10000000.0
# 93) Bestie - Camera360 Selfie : 10000000.0
# 94) Beauty Makeup Snappy Collage Photo Editor - Lidow : 10000000.0
# 95) Background Eraser : 10000000.0
# 96) AfterFocus : 10000000.0
# 97) ASUS PixelMaster Camera : 10000000.0
# 98) A+ Gallery - Photos & Videos : 10000000.0
# 99) Visage Lab – face retouch : 5000000.0
# 100) Sweet Camera : 5000000.0
# 101) SuperPhoto - Effects & Filters : 5000000.0
# 102) Story Saver for Instagram : 5000000.0
# 103) Silent Camera [High Quality] : 5000000.0
# 104) Shutterfly: Free Prints, Photo Books, Cards, Gifts : 5000000.0
# 105) Pretty Makeup, Beauty Photo Editor & Snappy Camera : 5000000.0
# 106) Pixgram- video photo slideshow : 5000000.0
# 107) Picture Grid Builder : 5000000.0
# 108) Photo Editor- : 5000000.0
# 109) Muzy - Share photos & collages : 5000000.0
# 110) Moto Photo Editor : 5000000.0
# 111) MIX by Camera360 : 5000000.0
# 112) Huji Cam : 5000000.0
# 113) High-Speed Camera (GIF,Burst) : 5000000.0
# 114) HD Camera - Best Cam with filters & panorama : 5000000.0
# 115) HD Camera : 5000000.0
# 116) Ghost In Photo : 5000000.0
# 117) Collage&Add Stickers papelook : 5000000.0
# 118) Change photo background : 5000000.0
# 119) Camera ZOOM FX - FREE : 5000000.0
# 120) Blur Image Background Editor (Blur Photo Editor) : 5000000.0
# 121) Blur Image - DSLR focus effect : 5000000.0
# 122) Adobe Photoshop Fix : 5000000.0
# 123) Adobe Illustrator Draw : 5000000.0
# 124) A Better Camera : 5000000.0
# 125) love : 1000000.0
# 126) XDV : 1000000.0
# 127) Waterfall Photo Frames : 1000000.0
# 128) Video Maker with Photo and Music : 1000000.0
# 129) Unicorn Photo : 1000000.0
# 130) Ultimate Background Eraser : 1000000.0
# 131) TouchNote: Cards & Gifts : 1000000.0
# 132) Thumbnail Maker : 1000000.0
# 133) Snapfish : 1000000.0
# 134) Snap Cat Face Camera : 1000000.0
# 135) Six Pack Abs Photo Editor : 1000000.0
# 136) Selfie Photo Editor : 1000000.0
# 137) Selfie Camera: Beauty Camera, Photo Editor,Collage : 1000000.0
# 138) Samsung SMART CAMERA App : 1000000.0
# 139) Pic Stitch - #1 Collage Maker : 1000000.0
# 140) Phogy, 3D Camera : 1000000.0
# 141) Pencil Photo Sketch-Sketching Drawing Photo Editor : 1000000.0
# 142) Night Photo Frame : 1000000.0
# 143) Mega Photo : 1000000.0
# 144) Makeup Photo Editor: Makeup Camera & Makeup Editor : 1000000.0
# 145) Makeup Editor -Beauty Photo Editor & Selfie Camera : 1000000.0
# 146) LightMeter Free : 1000000.0
# 147) LALALAB prints your photos, photobooks and magnets : 1000000.0
# 148) Kids Photo Frames : 1000000.0
# 149) KVAD Camera +: Selfie, Photo Filter, Grids : 1000000.0
# 150) InstaCam - Camera for Selfie : 1000000.0
# 151) Insave-Download for Instagram : 1000000.0
# 152) Hypocam : 1000000.0
# 153) HD Camera Pro for Android : 1000000.0
# 154) HD Camera - silent shutter : 1000000.0
# 155) HD Camera - Quick Snap Photo & Video : 1000000.0
# 156) FreePrints – Free Photos Delivered : 1000000.0
# 157) Footej Camera : 1000000.0
# 158) FilterGrid - Cam&Photo Editor : 1000000.0
# 159) F-Stop Gallery : 1000000.0
# 160) Ez iCam : 1000000.0
# 161) DSLR Camera Hd Ultra Professional : 1000000.0
# 162) Cut Out : Background Eraser and background changer : 1000000.0
# 163) Canon CameraWindow : 1000000.0
# 164) Camera51 - a smarter camera : 1000000.0
# 165) Camera Pro : 1000000.0
# 166) Blur : 1000000.0
# 167) Beauty Makeup – Photo Makeover : 1000000.0
# 168) BQ Camera : 1000000.0
# 169) Auto Background Changer : 1000000.0
# 170) Afterlight : 1000000.0
# 171) Add Watermark Free : 1000000.0
# 172) Add Text To Photo : 1000000.0
# 173) easyFocus : 500000.0
# 174) camera zoom moon : 500000.0
# 175) U Camera : Phone 6s OS 9 style : 500000.0
# 176) Sweet Snap Lite - live filter, Selfie photo editor : 500000.0
# 177) How Do I Look : 500000.0
# 178) Groovebook Photo Books & Gifts : 500000.0
# 179) Garden Photo Frames - Garden Photo Editor : 500000.0
# 180) DU GIF Maker: GIF Maker, Video to GIF & GIF Editor : 500000.0
# 181) Brica BPRO5 AE : 500000.0
# 182) Blurfoto : Auto blur photo background & DSLR focus : 500000.0
# 183) Background Changer & Eraser : 500000.0
# 184) BT Camera : 500000.0
# 185) ez Share Android app : 100000.0
# 186) V.360° Camera : 100000.0
# 187) SportLook : 100000.0
# 188) Picai - Smart AI Camera : 100000.0
# 189) Photo frame : 100000.0
# 190) Gold Teeth Photo Editor : 100000.0
# 191) Fifa World Cup 2018: Photo Frame Editor & DP Maker : 100000.0
# 192) DU Collage Maker - Photo Collage & Grid & Layout : 100000.0
# 193) DSLR Photography Training apps : 100000.0
# 194) DP Maker : 100000.0
# 195) DP Creator for WhatsApp : 100000.0
# 196) Cover Camera for FB : 100000.0
# 197) Camera V7 24 Megapixel : 100000.0
# 198) Black & White Camera - Lovely BW : 100000.0
# 199) B Tiff Viewer : 100000.0
# 200) AZ Camera - Manual Pro Cam : 100000.0
# 201) 4K Ultra Camera : 100000.0
# 202) 24 megapixel hd camera : 100000.0
# 203) Wifi Action Camera : 50000.0
# 204) Moony Lab - Print Photos, Books & Magnets ™ : 50000.0
# 205) DV Lottery Photo Tool : 50000.0
# 206) DP Status 2017 : 50000.0
# 207) BlitzWolf Shutter - BW Shutter : 50000.0
# 208) B&W Photo Filter Editor : 50000.0
# 209) Z Camera : 10000.0
# 210) Square DP For Whatsapp : 10000.0
# 211) Profile w/o crop for Telegram : 10000.0
# 212) Night Camera Blur Effect : 10000.0
# 213) Leica Q : 10000.0
# 214) FN Cam : 10000.0
# 215) FH WiFiCam : 10000.0
# 216) DSLR camera - Auto Focus and Blur Professional : 10000.0
# 217) DP Photo Editor : 10000.0
# 218) DF Night Selfies : 10000.0
# 219) DENVER ACTION CAM 3 : 10000.0
# 220) Be Fabulous PHOTO BOOTH : 10000.0
# 221) BL 1-Click Camera - Free : 10000.0
# 222) Insta Square Profile DP : 5000.0
# 223) FL Drone 2 : 5000.0
# 224) DP Editor : 5000.0
# 225) CB Edits PNG & CB Backgrounds : 5000.0
# 226) Photo Editor - BPhoto : 1000.0
# 227) Photo BG Changer : 1000.0
# 228) PIP-Camera FN Photo Effect : 1000.0
# 229) Magical Insta DP : 1000.0
# 230) Live DV : 1000.0
# 231) Light Meter - EV : 1000.0
# 232) Leica CL : 1000.0
# 233) FB Photographie : 1000.0
# 234) Dp For FB : 1000.0
# 235) DV-4036 by Somikon : 1000.0
# 236) DS-L4 Viewer : 1000.0
# 237) BK Photography : 1000.0
# 238) Auto Dslr Photo Effect : Auto Focus Effect : 1000.0
# 239) All Types DP & Status Maker : 1000.0
# 240) AEE AP : 1000.0
# 241) Selfie With Champion AJ Style : 500.0
# 242) DC-014 : 500.0
# 243) CB Hair Png - New Hair Png For CB Editing : 500.0
# 244) BC Camera : 500.0
# 245) AI Image Recognizer (beta) : 500.0
# 246) Wallpaper.cz : 100.0
# 247) LC-DB-LITE : 100.0
# 248) FD Fotografia : 100.0
# 249) DV KING 4K : 100.0
# 250) DV KING : 100.0
# 251) CG Prints : 100.0
# 252) CB VIDEO VISION : 100.0
# 253) Blender BG - Photo Blend With Background : 100.0
# 254) BL Portfolio : 100.0
# 255) Analog BW - Camera filter effect foto film retouch : 100.0
# 256) AJ Cam : 100.0
# 257) A.J. Styles HD Wallpapers 2018 : 100.0
# 258) Touch DV : 50.0
# 259) Displaying You VR : 50.0
# 260) i am EB : 10.0
# 261) BG Editor : 5.0

# %%
sort_cat_android(free_android, 'PRODUCTIVITY')
# Out:
# 1) Google Drive : 1000000000.0
# 2) Microsoft Word : 500000000.0
# 3) Google Calendar : 500000000.0
# 4) Dropbox : 500000000.0
# 5) Cloud Print : 500000000.0
# 6) WPS Office - Word, Docs, PDF, Note, Slide & Sheet : 100000000.0
# 7) SwiftKey Keyboard : 100000000.0
# 8) Samsung Notes : 100000000.0
# 9) Microsoft PowerPoint : 100000000.0
# 10) Microsoft Outlook : 100000000.0
# 11) Microsoft OneNote : 100000000.0
# 12) Microsoft OneDrive : 100000000.0
# 13) Microsoft Excel : 100000000.0
# 14) Google Slides : 100000000.0
# 15) Google Sheets : 100000000.0
# 16) Google Keep : 100000000.0
# 17) Google Docs : 100000000.0
# 18) Evernote – Organizer, Planner for Notes & Memos : 100000000.0
# 19) ES File Explorer File Manager : 100000000.0
# 20) ColorNote Notepad Notes : 100000000.0
# 21) CamScanner - Phone PDF Creator : 100000000.0
# 22) Adobe Acrobat Reader : 100000000.0
# 23) myAT&T : 50000000.0
# 24) Verizon Cloud : 50000000.0
# 25) QR Droid : 50000000.0
# 26) My Airtel-Online Recharge, Pay Bill, Wallet, UPI : 50000000.0
# 27) Mobizen Screen Recorder - Record, Capture, Edit : 50000000.0
# 28) MEGA : 50000000.0
# 29) File Browser by Astro (File Manager) : 50000000.0
# 30) Do It Later: Tasks & To-Dos : 50000000.0
# 31) Calculator - unit converter : 50000000.0
# 32) Alarm Clock: Stopwatch & Timer : 50000000.0
# 33) Advanced Task Killer : 50000000.0
# 34) iTranslate Translator & Dictionary : 10000000.0
# 35) aCalendar - Android Phone : 10000000.0
# 36) Wunderlist: To-Do List & Tasks : 10000000.0
# 37) U+Box : 10000000.0
# 38) Todoist: To-do lists for task management & errands : 10000000.0
# 39) S Note : 10000000.0
# 40) QR Scanner & Barcode Scanner 2018 : 10000000.0
# 41) Polaris Office - Word, Docs, Sheets, Slide, PDF : 10000000.0
# 42) Notepad & To do list : 10000000.0
# 43) Notepad : 10000000.0
# 44) NQ Mobile Security & Antivirus : 10000000.0
# 45) MyVodafone (India) - Online Recharge & Pay Bills : 10000000.0
# 46) Mobile Security: Antivirus, Web Scan & App Lock : 10000000.0
# 47) Mobile Security & Antivirus : 10000000.0
# 48) Metro name iD : 10000000.0
# 49) LOCX Applock Lock Apps & Photo : 10000000.0
# 50) Keeper: Free Password Manager & Secure Vault : 10000000.0
# 51) Jorte Calendar & Organizer : 10000000.0
# 52) HTC Mail : 10000000.0
# 53) HTC File Manager : 10000000.0
# 54) HTC Calendar : 10000000.0
# 55) Google PDF Viewer : 10000000.0
# 56) Google Assistant : 10000000.0
# 57) Fake Call - Fake Caller ID : 10000000.0
# 58) Easy Voice Recorder : 10000000.0
# 59) Chrome Beta : 10000000.0
# 60) CM FILE MANAGER HD : 10000000.0
# 61) AutoCAD - DWG Viewer & Editor : 10000000.0
# 62) Any.do: To-do list, Calendar, Reminders & Planner : 10000000.0
# 63) AndroZip™ FREE File Manager : 10000000.0
# 64) All-In-One Toolbox: Cleaner, Booster, App Manager : 10000000.0
# 65) AVG Cleaner – Speed, Battery & Memory Booster : 10000000.0
# 66) AT&T Mobile Transfer : 10000000.0
# 67) ASUS SuperNote : 10000000.0
# 68) ASUS Quick Memo : 10000000.0
# 69) ASUS Calling Screen : 10000000.0
# 70) APUS Booster - Space Cleaner & Booster : 10000000.0
# 71) lifebox : 5000000.0
# 72) Yandex.Disk : 5000000.0
# 73) Ultimate Notepad : 5000000.0
# 74) Trello : 5000000.0
# 75) To Do List : 5000000.0
# 76) The Maner : 5000000.0
# 77) PDF Viewer & Book Reader : 5000000.0
# 78) Note Everything : 5000000.0
# 79) My Claro Peru : 5000000.0
# 80) Microsoft Translator : 5000000.0
# 81) MediaFire : 5000000.0
# 82) Keep My Notes - Notepad & Memo : 5000000.0
# 83) Ginger Keyboard - Emoji, GIFs, Themes & Games : 5000000.0
# 84) G Cloud Backup : 5000000.0
# 85) EBookDroid - PDF & DJVU Reader : 5000000.0
# 86) DigiCal Calendar Agenda : 5000000.0
# 87) Content Transfer : 5000000.0
# 88) Clean My Android : 5000000.0
# 89) Calendar Widget Month + Agenda : 5000000.0
# 90) Business Calendar 2 : 5000000.0
# 91) Archos File Manager : 5000000.0
# 92) pCloud: Free Cloud Storage : 1000000.0
# 93) e-Boks.dk : 1000000.0
# 94) Ultimate Chest Tracker : 1000000.0
# 95) Today Calendar 2017 : 1000000.0
# 96) To-Do List Widget : 1000000.0
# 97) To-Do Calendar Planner : 1000000.0
# 98) To Do Reminder with Alarm : 1000000.0
# 99) Time Recording - Timesheet App : 1000000.0
# 100) TickTick: To Do List with Reminder, Day Planner : 1000000.0
# 101) S’more - Earn Cash Rewards : 1000000.0
# 102) SugarSync : 1000000.0
# 103) Sticky Note + : Sync Notes : 1000000.0
# 104) Squid - Take Notes & Markup PDFs : 1000000.0
# 105) Solid Explorer File Manager : 1000000.0
# 106) Solid Explorer Classic : 1000000.0
# 107) Smart File Manager : 1000000.0
# 108) Simple Notepad : 1000000.0
# 109) Security & Privacy : 1000000.0
# 110) Resume Free : 1000000.0
# 111) Pushbullet - SMS on PC : 1000000.0
# 112) Power Booster - Junk Cleaner & CPU Cooler & Boost : 1000000.0
# 113) Planner Pro-Personal Organizer : 1000000.0
# 114) Phone Clean Best Speed Booster : 1000000.0
# 115) NoteToDo. Notes. To do list : 1000000.0
# 116) New Calendar : 1000000.0
# 117) Můj T-Mobile Business : 1000000.0
# 118) MyMTN : 1000000.0
# 119) Multiling O Keyboard + emoji : 1000000.0
# 120) Microsoft To-Do: List, Task & Reminder : 1000000.0
# 121) Mahalaxmi Dindarshika 2018 : 1000000.0
# 122) Lyra Virtual Assistant : 1000000.0
# 123) Loop - Habit Tracker : 1000000.0
# 124) JotterPad - Writer, Screenplay, Novel : 1000000.0
# 125) IFTTT : 1000000.0
# 126) Hacker's Keyboard : 1000000.0
# 127) Google AdSense : 1000000.0
# 128) Extreme- Personal Voice Assistant : 1000000.0
# 129) Epson iProjection : 1000000.0
# 130) Emoji Android L Keyboard : 1000000.0
# 131) EX File Explorer File Manager : 1000000.0
# 132) ES Material Theme for Pro : 1000000.0
# 133) Do it (Tomorrow) : 1000000.0
# 134) Dashlane Free Password Manager : 1000000.0
# 135) DS file : 1000000.0
# 136) Cozi Family Organizer : 1000000.0
# 137) Chrome Canary (Unstable) : 1000000.0
# 138) Chelsea FC Official Keyboard : 1000000.0
# 139) Calendar+ Schedule Planner App : 1000000.0
# 140) Cal - Google Calendar + Widget : 1000000.0
# 141) CY Security Antivirus Cleaner : 1000000.0
# 142) Avast Wi-Fi Finder : 1000000.0
# 143) Amazon Drive : 1000000.0
# 144) Adobe Fill & Sign: Easy PDF Form Filler : 1000000.0
# 145) Adblock Fast : 1000000.0
# 146) ALL-IN-ONE PACKAGE TRACKING : 1000000.0
# 147) AL Voice Recorder : 1000000.0
# 148) Ultimate Calculator for CR : 500000.0
# 149) Time Planner - Schedule, To-Do List, Time Tracker : 500000.0
# 150) T-Mobile Content Transfer : 500000.0
# 151) Q Link Wireless Zone : 500000.0
# 152) Planning Center Services : 500000.0
# 153) Official QR Code® Reader "Q" : 500000.0
# 154) My Effectiveness: To do, Tasks : 500000.0
# 155) Memory Helper - To do list, Notepad, Notes, Memo : 500000.0
# 156) ES Holo Theme for Pro : 500000.0
# 157) DS cam : 500000.0
# 158) Ad Detect Plugin - Handy Tool : 500000.0
# 159) A-Z App Store : 500000.0
# 160) 7 Weeks - Habit & Goal Tracker : 500000.0
# 161) cm, mm to inch, feet converter tool : 100000.0
# 162) Unclouded - Cloud Manager : 100000.0
# 163) Total AV : 100000.0
# 164) TIMBER AD FILTER - Very useful ad block app : 100000.0
# 165) Synology Drive : 100000.0
# 166) Resume Builder and CV maker app : 100000.0
# 167) Pocket RxTx Free : 100000.0
# 168) MyLifeOrganized: To-Do List : 100000.0
# 169) Inch/cm/Foot Conversion : 100000.0
# 170) Ike - To-Do List, Task List : 100000.0
# 171) IQ Test : 100000.0
# 172) IDM for Facebook ★ Downloader : 100000.0
# 173) IDM Internet Download Manager : 100000.0
# 174) Goal Meter: Goal Tracker, Habit Changer,To-Do List : 100000.0
# 175) Future Cloud : 100000.0
# 176) Friday: Smart Personal Assistant : 100000.0
# 177) File Explorer : 100000.0
# 178) Exército Brasileiro : 100000.0
# 179) EZ Switch Widget : 100000.0
# 180) EZ File Manager(Root Explorer) : 100000.0
# 181) ES Disk Analyzer - Storage Space : 100000.0
# 182) Dz Dinars Numbers to letters : 100000.0
# 183) Dr.Android Repair Master 2017 : 100000.0
# 184) Download Manager Pro FREE : 100000.0
# 185) Do Not Disturb : 100000.0
# 186) DS note : 100000.0
# 187) Clean My House – Chore To Do List, Task Scheduler : 100000.0
# 188) Calculator L : 100000.0
# 189) Bits Watch Face : 100000.0
# 190) Best Applock - Locker & No Ads : 100000.0
# 191) 2Do - Reminders, To-do List & Notes : 100000.0
# 192) WiFi-o-Matic : 50000.0
# 193) WFVS 2018 | WhatApp Full Video Status & Downloader : 50000.0
# 194) U Assist - Screen Mirroring & Sharing App : 50000.0
# 195) To-do list : 50000.0
# 196) Safe Notes - Secure Ad-free notepad : 50000.0
# 197) SH Script Runner : 50000.0
# 198) Numbers Into Words : 50000.0
# 199) My C Spire : 50000.0
# 200) MultiMessage for FB Messenger : 50000.0
# 201) Inputting Plus: Ctrl + Z/F/C/V : 50000.0
# 202) EZ Display : 50000.0
# 203) ESLock File Recovery Lite : 50000.0
# 204) CTRL-F - Search the real world : 50000.0
# 205) BJ Memo Widget : 50000.0
# 206) Add-On: Alcatel (h) : 50000.0
# 207) ai.Bot Box : 10000.0
# 208) Wi-Fi Networks : 10000.0
# 209) Trimble DL : 10000.0
# 210) Trimble Ag Mobile : 10000.0
# 211) Tap N Pay : 10000.0
# 212) Solar CT PV System Power : 10000.0
# 213) Remote Control For All AC - Universal Remote : 10000.0
# 214) N Files - File Manager & Explorer : 10000.0
# 215) Mix Tank – Tank Mixing Ag App : 10000.0
# 216) Larry H Miller Automotive : 10000.0
# 217) Eurostat Country Profiles : 10000.0
# 218) Electricity Bill Calculator BD : 10000.0
# 219) EZ Inspections : 10000.0
# 220) EC Taximeter : 10000.0
# 221) DG Report Reminder : 10000.0
# 222) Curriculum Vitae - Resume CV : 10000.0
# 223) CD Library : 10000.0
# 224) Alt-C : 10000.0
# 225) Turbo AI™ - Personal assistant : 5000.0
# 226) Resume & CV Creator by Desygner : 5000.0
# 227) R-net for Android : 5000.0
# 228) Mind Map AR, Augmented Reality ARCore Mind Mapping : 5000.0
# 229) EU Economy : 5000.0
# 230) ESS Mobile for AE : 5000.0
# 231) CG - Calendars Add-On : 5000.0
# 232) Bomb and Nade Timer for CS:GO : 5000.0
# 233) BA Calculator : 5000.0
# 234) Air Conditioner Maintenance : 5000.0
# 235) Add-On: bq (a) : 5000.0
# 236) AP ENPS Mobile : 5000.0
# 237) Simple EV Calc : 1000.0
# 238) Sai Baba - Sabka Malik Ek : 1000.0
# 239) Safe Wi-Fi : 1000.0
# 240) Puck AI Personal Assistant Robot : 1000.0
# 241) Professional AV Solution & Products information : 1000.0
# 242) New Holland Agriculture T5 EC : 1000.0
# 243) My CU - Caucasus University : 1000.0
# 244) Krypton by krypt.co : 1000.0
# 245) Fayr - Co-Parenting Simplified : 1000.0
# 246) FQ METER : 1000.0
# 247) FL House : 1000.0
# 248) EZ Notes Lite : 1000.0
# 249) EF Calculator : 1000.0
# 250) DS-20000S : 1000.0
# 251) DG Phone Call Task Switcher : 1000.0
# 252) DB Manager : 1000.0
# 253) Commission Manager : 1000.0
# 254) CircleCI Viewer : 1000.0
# 255) Charlotte County, FL : 1000.0
# 256) Calendars (En, Bn, Ar) : 1000.0
# 257) CG - Conference Call Add-On : 1000.0
# 258) CA World '17 : 1000.0
# 259) BG+Phone Backup : 1000.0
# 260) BD Field Force : 1000.0
# 261) BD Attendance : 1000.0
# 262) Ag PhD Soils : 1000.0
# 263) Add-On: bq (c) : 1000.0
# 264) Add-On: bq (b) : 1000.0
# 265) AI Sight : 1000.0
# 266) Tips Microsoft Dynamics Ax : 500.0
# 267) Q Actions - Digital Assistant : 500.0
# 268) IP address BW : 500.0
# 269) Florida Cooling Supply HVAC : 500.0
# 270) Fast Notes FJ : 500.0
# 271) Ek Vote : 500.0
# 272) EY Events Switzerland : 500.0
# 273) EY ATL Fuel Calculator : 500.0
# 274) DT Manager : 500.0
# 275) DN Events : 500.0
# 276) CP Connect 2.0 : 500.0
# 277) CJ Wilson's ZoomZoomnation : 500.0
# 278) BZ Dealer : 500.0
# 279) iReadMe : 100.0
# 280) ec-Work : 100.0
# 281) eG Monitor : 100.0
# 282) Town of Princeton, BC : 100.0
# 283) Tips & Tricks Dynamics AX 365 : 100.0
# 284) Thistletown CI : 100.0
# 285) Somos CG : 100.0
# 286) SCS eC : 100.0
# 287) RoutePlan.cz : 100.0
# 288) Register.ca Mobile : 100.0
# 289) MiAI (Artificial Intelligence) Assistant : 100.0
# 290) Mat|r viewer : 100.0
# 291) K-App Mitarbeiter Galeria Kaufhof : 100.0
# 292) J. Polep Plus Mobile : 100.0
# 293) Fort Myers FL : 100.0
# 294) ES Billing System (Offline App) : 100.0
# 295) EP Home Energy Hub : 100.0
# 296) EG : 100.0
# 297) EF Staff : 100.0
# 298) DG Users : 100.0
# 299) DF-Server Mobile : 100.0
# 300) Cx Wize : 100.0
# 301) CJ'S TIRE AND AUTO INC. : 100.0
# 302) CI Time : 100.0
# 303) CI Remote for Go : 100.0
# 304) CI CAFETERIAS UBER : 100.0
# 305) Builder (by Engineer.ai) : 100.0
# 306) BW-IVMS : 100.0
# 307) BV Mobile Apps : 100.0
# 308) Ag Trucking Mobile App : 100.0
# 309) Ag Guardian : 100.0
# 310) My Ag Report : 50.0
# 311) MY GULFPORT FL : 50.0
# 312) EY Team Connect : 50.0
# 313) EB Scanner : 50.0
# 314) CX Summit : 50.0
# 315) CT CONNECT : 50.0
# 316) CONNECT: The Mobile CX Summit : 50.0
# 317) CE SODEXO PASS FRANCE : 50.0
# 318) BN DB1 App : 50.0
# 319) BAMMS for BM 1Park : 50.0
# 320) SKIN BK : 10.0
# 321) PLMGSS FR : 10.0
# 322) My CG : 10.0
# 323) MinT BI : 10.0
# 324) EU Brazil Green Business Forum : 10.0
# 325) ER Assist : 10.0
# 326) EP Cloud : 10.0
# 327) EI! : 10.0
# 328) EC QR : 10.0
# 329) DV Web Design Tips : 10.0
# 330) CQ Ukraine : 10.0
# 331) BW t&t : 10.0
# 332) BW Ultra : 10.0
# 333) BN Inscript Improved Keyboard : 10.0
# 334) BN Inscript Improved Input keyboard : 10.0
# 335) BM Interventi : 10.0
# 336) BAMMS for BM SQ : 10.0
# 337) AQ Guards : 10.0
# 338) APagri CD : 10.0
# 339) ACCEPT CE MARKING : 10.0
# 340) Shaggy's DM Assistant : 5.0
# 341) FK Events : 5.0
# 342) EC Sampler : 1.0
# 343) DZ Register : 1.0
# 344) DT Freight : 1.0
# 345) CQ Electrical Group : 1.0

# %% [markdown]
# We see the same pattern for the video players category, which is the runner-up with 24,727,872 installs. The market is dominated by apps like Youtube, Google Play Movies & TV, or MX Player. The pattern is repeated for social apps (where we have giants like Facebook, Instagram, Google+, etc.), photography apps (Google Photos and other popular photo editors), or productivity apps (Microsoft Word, Dropbox, Google Calendar, Evernote, etc.).
#
# ## Conclusion
#
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# The video player category would be a good profile for the app as you could embed ads into the videos. This is also similar to the music genre in the app store.
#
# If we were to create an app that focused on music videos and maybe allow for some sort of social networking it could be quite successful. We would also be able to play ads through the video player.
